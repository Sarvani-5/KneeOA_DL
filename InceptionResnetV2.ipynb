# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvani-5/KneeOA_DL/blob/main/InceptionResnetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import inception_resnet_v2

# Load InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input

# Define class mapping
knee_classes = {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
class_names = list(knee_classes.keys())

# Enhanced data loader that combines both datasets
def load_combined_data(exp1_path, exp2_path, image_size=224):  # InceptionResNetV2 typically uses 224x224
    X, y = [], []

    # Load MedicalExpert-I
    print("Loading MedicalExpert-I...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp1_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    # Load MedicalExpert-II
    print("\nLoading MedicalExpert-II...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp2_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    return np.array(X), np.array(y)

# Paths to your datasets - UPDATE THESE
medical_expert_I_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-I"
medical_expert_II_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-II"

# Load combined data
X, y = load_combined_data(medical_expert_I_path, medical_expert_II_path)

# Check class distribution
print("\nClass distribution in combined dataset:")
for class_name, class_idx in knee_classes.items():
    print(f"{class_name}: {np.sum(y == class_idx)} samples")

# Convert to float32 and preprocess for InceptionResNetV2
X = X.astype('float32')
X = preprocess_input(X)  # Preprocess for InceptionResNetV2
y = to_categorical(y, num_classes=5)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print(f"\nTraining samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")

# Data augmentation for training set
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='constant',
    cval=0
)

# Build model using InceptionResNetV2
def build_inception_resnet_model():
    base_model = InceptionResNetV2(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )

    # Freeze the base model layers first
    base_model.trainable = False

    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(5, activation='softmax')(x)

    model = Model(inputs, outputs)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model, base_model

model, base_model = build_inception_resnet_model()
model.summary()

# Define the single best model path
best_model_path = '/content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras'

# Callbacks
callbacks = [
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=1e-6, verbose=1),
    ModelCheckpoint(
        filepath=best_model_path,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

# First phase - train with frozen base model
print("\nTraining top layers with frozen InceptionResNetV2 base...")
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=32),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Unfreeze some layers for fine-tuning
print("\nUnfreezing later InceptionResNetV2 layers for fine-tuning...")
base_model.trainable = True
# InceptionResNetV2 is a deep model - freeze earlier layers
# We'll keep approximately the first 50% of the network frozen
num_layers = len(base_model.layers)
for layer in base_model.layers[:int(0.5 * num_layers)]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("\nFine-tuning model...")
history_fine = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=16),
    epochs=150,
    initial_epoch=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Combine histories
combined_history = {}
for key in history.history:
    combined_history[key] = history.history[key] + history_fine.history[key]

# Load the best model for evaluation
print(f"\nLoading the best model from {best_model_path}")
best_model = load_model(best_model_path)

# Evaluate the best model
y_pred = np.argmax(best_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('/content/drive/MyDrive/KneeOA/inception_resnet_confusion_matrix.png')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(combined_history['accuracy'], label='Train Accuracy')
plt.plot(combined_history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_history['loss'], label='Train Loss')
plt.plot(combined_history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/content/drive/MyDrive/KneeOA/inception_resnet_training_history.png')
plt.show()

# Sample predictions
def predict_sample_images(model, X_test, y_test, num_samples=5):
    sample_indices = np.random.choice(len(X_test), num_samples, replace=False)

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(sample_indices, 1):
        image = X_test[idx]
        true_class = np.argmax(y_test[idx])

        # Make prediction
        pred_probs = model.predict(np.expand_dims(image, axis=0))
        pred_class = np.argmax(pred_probs)

        # Convert image back for display
        image = (image - image.min()) / (image.max() - image.min())  # Normalize to 0-1

        plt.subplot(1, num_samples, i)
        plt.imshow(image)
        plt.title(f"True: {class_names[true_class]}\nPred: {class_names[pred_class]}")
        plt.axis('off')

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/KneeOA/inception_resnet_sample_predictions.png')
    plt.show()

# Display sample predictions
print("\nSample predictions on test set:")
predict_sample_images(best_model, X_test, y_test, num_samples=5)

print(f"\nThe best model has been saved to: {best_model_path}")
# Out:
# Loading MedicalExpert-I...
# Processing 0Normal... Loaded 514 samples
# Processing 1Doubtful... Loaded 477 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Loading MedicalExpert-II...
# Processing 0Normal... Loaded 504 samples
# Processing 1Doubtful... Loaded 488 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Class distribution in combined dataset:
# 0Normal: 1018 samples
# 1Doubtful: 965 samples
# 2Mild: 464 samples
# 3Moderate: 442 samples
# 4Severe: 412 samples
#
# Training samples: 2640
# Test samples: 661
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_resnet_v2             │ (None, 5, 5, 1536)     │    54,336,736 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 38400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    19,661,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_203         │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_204         │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 74,133,733 (282.80 MB)
#  Trainable params: 19,795,461 (75.51 MB)
#  Non-trainable params: 54,338,272 (207.28 MB)
# Training top layers with frozen InceptionResNetV2 base...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.3312 - loss: 2.1479
# Epoch 1: val_accuracy improved from -inf to 0.36006, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.3318 - loss: 2.1461 - val_accuracy: 0.3601 - val_loss: 2.1502 - learning_rate: 1.0000e-04
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.4598 - loss: 1.6999
# Epoch 2: val_accuracy improved from 0.36006 to 0.51740, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 532ms/step - accuracy: 0.4601 - loss: 1.6991 - val_accuracy: 0.5174 - val_loss: 1.2487 - learning_rate: 1.0000e-04
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.5021 - loss: 1.5209
# Epoch 3: val_accuracy did not improve from 0.51740
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.5021 - loss: 1.5208 - val_accuracy: 0.5129 - val_loss: 1.2107 - learning_rate: 1.0000e-04
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.4986 - loss: 1.5076
# Epoch 4: val_accuracy improved from 0.51740 to 0.64448, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 506ms/step - accuracy: 0.4988 - loss: 1.5073 - val_accuracy: 0.6445 - val_loss: 1.0085 - learning_rate: 1.0000e-04
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.5206 - loss: 1.3906
# Epoch 5: val_accuracy improved from 0.64448 to 0.66263, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 563ms/step - accuracy: 0.5208 - loss: 1.3902 - val_accuracy: 0.6626 - val_loss: 0.9450 - learning_rate: 1.0000e-04
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.5445 - loss: 1.3500
# Epoch 6: val_accuracy improved from 0.66263 to 0.67322, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 78s 509ms/step - accuracy: 0.5446 - loss: 1.3499 - val_accuracy: 0.6732 - val_loss: 1.0862 - learning_rate: 1.0000e-04
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.5755 - loss: 1.2943
# Epoch 7: val_accuracy improved from 0.67322 to 0.67776, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 537ms/step - accuracy: 0.5756 - loss: 1.2935 - val_accuracy: 0.6778 - val_loss: 0.9004 - learning_rate: 1.0000e-04
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.5957 - loss: 1.1710
# Epoch 8: val_accuracy did not improve from 0.67776
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 512ms/step - accuracy: 0.5955 - loss: 1.1715 - val_accuracy: 0.6369 - val_loss: 1.1261 - learning_rate: 1.0000e-04
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6016 - loss: 1.1633
# Epoch 9: val_accuracy improved from 0.67776 to 0.70802, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.6016 - loss: 1.1631 - val_accuracy: 0.7080 - val_loss: 0.8416 - learning_rate: 1.0000e-04
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.6264 - loss: 1.1019
# Epoch 10: val_accuracy did not improve from 0.70802
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.6263 - loss: 1.1021 - val_accuracy: 0.6959 - val_loss: 0.8370 - learning_rate: 1.0000e-04
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.6198 - loss: 1.0649
# Epoch 11: val_accuracy did not improve from 0.70802
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 402ms/step - accuracy: 0.6198 - loss: 1.0653 - val_accuracy: 0.6914 - val_loss: 0.7968 - learning_rate: 1.0000e-04
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.5915 - loss: 1.1127
# Epoch 12: val_accuracy improved from 0.70802 to 0.73828, saving model to /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 601ms/step - accuracy: 0.5917 - loss: 1.1126 - val_accuracy: 0.7383 - val_loss: 0.7115 - learning_rate: 1.0000e-04
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/
150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9676 - loss: 0.1097
# Epoch 139: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 271ms/step - accuracy: 0.9676 - loss: 0.1097 - val_accuracy: 0.9274 - val_loss: 0.2374 - learning_rate: 1.0000e-06
# Epoch 140/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9473 - loss: 0.1367
# Epoch 140: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 47s 281ms/step - accuracy: 0.9473 - loss: 0.1367 - val_accuracy: 0.9289 - val_loss: 0.2378 - learning_rate: 1.0000e-06
# Epoch 141/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9709 - loss: 0.0948
# Epoch 141: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 267ms/step - accuracy: 0.9709 - loss: 0.0948 - val_accuracy: 0.9289 - val_loss: 0.2382 - learning_rate: 1.0000e-06
# Epoch 142/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9675 - loss: 0.1052
# Epoch 142: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 82s 267ms/step - accuracy: 0.9675 - loss: 0.1052 - val_accuracy: 0.9289 - val_loss: 0.2348 - learning_rate: 1.0000e-06
# Epoch 143/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9690 - loss: 0.0935
# Epoch 143: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 82s 267ms/step - accuracy: 0.9690 - loss: 0.0936 - val_accuracy: 0.9304 - val_loss: 0.2360 - learning_rate: 1.0000e-06
# Epoch 144/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9708 - loss: 0.1022
# Epoch 144: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 46s 281ms/step - accuracy: 0.9708 - loss: 0.1022 - val_accuracy: 0.9319 - val_loss: 0.2327 - learning_rate: 1.0000e-06
# Epoch 145/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9753 - loss: 0.0988
# Epoch 145: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 266ms/step - accuracy: 0.9753 - loss: 0.0989 - val_accuracy: 0.9304 - val_loss: 0.2305 - learning_rate: 1.0000e-06
# Epoch 146/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9618 - loss: 0.1204
# Epoch 146: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 83s 272ms/step - accuracy: 0.9618 - loss: 0.1205 - val_accuracy: 0.9289 - val_loss: 0.2352 - learning_rate: 1.0000e-06
# Epoch 147/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9707 - loss: 0.1000
# Epoch 147: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 274ms/step - accuracy: 0.9707 - loss: 0.1000 - val_accuracy: 0.9319 - val_loss: 0.2341 - learning_rate: 1.0000e-06
# Epoch 148/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9689 - loss: 0.1026
# Epoch 148: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 81s 270ms/step - accuracy: 0.9689 - loss: 0.1026 - val_accuracy: 0.9304 - val_loss: 0.2347 - learning_rate: 1.0000e-06
# Epoch 149/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9754 - loss: 0.0844
# Epoch 149: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 47s 285ms/step - accuracy: 0.9753 - loss: 0.0845 - val_accuracy: 0.9319 - val_loss: 0.2314 - learning_rate: 1.0000e-06
# Epoch 150/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9582 - loss: 0.1279
# Epoch 150: val_accuracy did not improve from 0.94251
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 46s 281ms/step - accuracy: 0.9582 - loss: 0.1280 - val_accuracy: 0.9334 - val_loss: 0.2323 - learning_rate: 1.0000e-06
#
# Loading the best model from /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 28s 715ms/step
#
# Confusion Matrix:
# [[195   9   0   0   0]
#  [  5 185   3   0   0]
#  [  0  13  75   5   0]
#  [  2   0   0  86   1]
#  [  0   0   0   0  82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      0Normal       0.97      0.96      0.96       204
#    1Doubtful       0.89      0.96      0.93       193
#        2Mild       0.96      0.81      0.88        93
#    3Moderate       0.95      0.97      0.96        89
#      4Severe       0.99      1.00      0.99        82
#
#     accuracy                           0.94       661
#    macro avg       0.95      0.94      0.94       661
# weighted avg       0.94      0.94      0.94       661
# Sample predictions on test set:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# The best model has been saved to: /content/drive/MyDrive/KneeOA/inception_resnet_best_model.keras
