# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvani-5/KneeOA_DL/blob/main/VGG16_KneeOA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

# Define class mapping
knee_classes = {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
class_names = list(knee_classes.keys())

# Enhanced data loader that combines both datasets
def load_combined_data(exp1_path, exp2_path, image_size=224):  # VGG typically uses 224x224
    X, y = [], []

    # Load MedicalExpert-I
    print("Loading MedicalExpert-I...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp1_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    # Load MedicalExpert-II
    print("\nLoading MedicalExpert-II...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp2_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    return np.array(X), np.array(y)

# Paths to your datasets - UPDATE THESE
medical_expert_I_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-I"
medical_expert_II_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-II"

# Load combined data
X, y = load_combined_data(medical_expert_I_path, medical_expert_II_path)

# Check class distribution
print("\nClass distribution in combined dataset:")
for class_name, class_idx in knee_classes.items():
    print(f"{class_name}: {np.sum(y == class_idx)} samples")

# Convert to float32 and preprocess for VGG16
X = X.astype('float32')
X = preprocess_input(X)  # Preprocess for VGG16
y = to_categorical(y, num_classes=5)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print(f"\nTraining samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")

# Data augmentation for training set
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='constant',
    cval=0
)

# Build model using VGG16
def build_vgg_model():
    base_model = VGG16(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )

    # Freeze the base model layers first
    base_model.trainable = False

    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(5, activation='softmax')(x)

    model = Model(inputs, outputs)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model, base_model

model, base_model = build_vgg_model()
model.summary()

# Define the single best model path
best_model_path = '/content/drive/MyDrive/KneeOA/best_vgg_model.keras'

# Callbacks - THIS IS THE KEY PART
# ModelCheckpoint will save the model after each epoch if validation accuracy improves
callbacks = [
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=1e-6, verbose=1),
    ModelCheckpoint(
        filepath=best_model_path,
        monitor='val_accuracy',
        save_best_only=True,  # Only save when val_accuracy improves
        mode='max',
        verbose=1
    )
]

# First phase - train with frozen base model
print("\nTraining top layers with frozen VGG16 base...")
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=32),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Unfreeze some layers for fine-tuning
print("\nUnfreezing later VGG layers for fine-tuning...")
base_model.trainable = True
# Keep early blocks frozen
for layer in base_model.layers[:15]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("\nFine-tuning model...")
history_fine = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=16),
    epochs=150,
    initial_epoch=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,  # Same callback - will continue updating the same best model
    verbose=1
)

# Combine histories
combined_history = {}
for key in history.history:
    combined_history[key] = history.history[key] + history_fine.history[key]

# Load the best model for evaluation
print(f"\nLoading the best model from {best_model_path}")
best_model = load_model(best_model_path)

# Evaluate the best model
y_pred = np.argmax(best_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('/content/drive/MyDrive/KneeOA/confusion_matrix_vgg.png')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(combined_history['accuracy'], label='Train Accuracy')
plt.plot(combined_history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_history['loss'], label='Train Loss')
plt.plot(combined_history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/content/drive/MyDrive/KneeOA/training_history_vgg.png')
plt.show()

# Sample predictions
def predict_sample_images(model, X_test, y_test, num_samples=5):
    sample_indices = np.random.choice(len(X_test), num_samples, replace=False)

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(sample_indices, 1):
        image = X_test[idx]
        true_class = np.argmax(y_test[idx])

        # Make prediction
        pred_probs = model.predict(np.expand_dims(image, axis=0))
        pred_class = np.argmax(pred_probs)

        # Convert image back for display
        image = (image - image.min()) / (image.max() - image.min())  # Normalize to 0-1

        plt.subplot(1, num_samples, i)
        plt.imshow(image)
        plt.title(f"True: {class_names[true_class]}\nPred: {class_names[pred_class]}")
        plt.axis('off')

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/KneeOA/sample_predictions_vgg.png')
    plt.show()

# Display sample predictions
print("\nSample predictions on test set:")
predict_sample_images(best_model, X_test, y_test, num_samples=5)

print(f"\nThe best model has been saved to: {best_model_path}")
# Out:
# Loading MedicalExpert-I...
# Processing 0Normal... Loaded 514 samples
# Processing 1Doubtful... Loaded 477 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Loading MedicalExpert-II...
# Processing 0Normal... Loaded 504 samples
# Processing 1Doubtful... Loaded 488 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Class distribution in combined dataset:
# 0Normal: 1018 samples
# 1Doubtful: 965 samples
# 2Mild: 464 samples
# 3Moderate: 442 samples
# 4Severe: 412 samples
#
# Training samples: 2640
# Test samples: 661
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,695,941 (105.65 MB)
#  Trainable params: 12,979,717 (49.51 MB)
#  Non-trainable params: 14,716,224 (56.14 MB)
# Training top layers with frozen VGG16 base...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.2867 - loss: 2.3465
# Epoch 1: val_accuracy improved from -inf to 0.45386, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 79s 811ms/step - accuracy: 0.2872 - loss: 2.3443 - val_accuracy: 0.4539 - val_loss: 1.6979 - learning_rate: 1.0000e-04
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.4086 - loss: 1.7417
# Epoch 2: val_accuracy improved from 0.45386 to 0.64297, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 481ms/step - accuracy: 0.4089 - loss: 1.7414 - val_accuracy: 0.6430 - val_loss: 0.9942 - learning_rate: 1.0000e-04
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.4951 - loss: 1.5269
# Epoch 3: val_accuracy improved from 0.64297 to 0.69894, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.4952 - loss: 1.5266 - val_accuracy: 0.6989 - val_loss: 0.9260 - learning_rate: 1.0000e-04
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.5263 - loss: 1.3675
# Epoch 4: val_accuracy improved from 0.69894 to 0.72163, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 487ms/step - accuracy: 0.5264 - loss: 1.3675 - val_accuracy: 0.7216 - val_loss: 0.8741 - learning_rate: 1.0000e-04
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.5610 - loss: 1.2272
# Epoch 5: val_accuracy did not improve from 0.72163
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 470ms/step - accuracy: 0.5610 - loss: 1.2276 - val_accuracy: 0.7110 - val_loss: 0.8641 - learning_rate: 1.0000e-04
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5818 - loss: 1.1827
# Epoch 6: val_accuracy improved from 0.72163 to 0.73676, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 433ms/step - accuracy: 0.5819 - loss: 1.1829 - val_accuracy: 0.7368 - val_loss: 0.7775 - learning_rate: 1.0000e-04
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.5928 - loss: 1.1461
# Epoch 7: val_accuracy did not improve from 0.73676
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 470ms/step - accuracy: 0.5930 - loss: 1.1457 - val_accuracy: 0.7307 - val_loss: 0.8430 - learning_rate: 1.0000e-04
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6234 - loss: 1.0778
# Epoch 8: val_accuracy improved from 0.73676 to 0.75189, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.6235 - loss: 1.0776 - val_accuracy: 0.7519 - val_loss: 0.7304 - learning_rate: 1.0000e-04
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.6373 - loss: 0.9888
# Epoch 9: val_accuracy improved from 0.75189 to 0.77307, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 462ms/step - accuracy: 0.6374 - loss: 0.9890 - val_accuracy: 0.7731 - val_loss: 0.6920 - learning_rate: 1.0000e-04
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.6505 - loss: 1.0278
# Epoch 10: val_accuracy did not improve from 0.77307
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 468ms/step - accuracy: 0.6505 - loss: 1.0275 - val_accuracy: 0.7458 - val_loss: 0.8082 - learning_rate: 1.0000e-04
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6532 - loss: 0.9882
# Epoch 11: val_accuracy did not improve from 0.77307
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.6533 - loss: 0.9883 - val_accuracy: 0.7549 - val_loss: 0.6962 - learning_rate: 1.0000e-04
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.6814 - loss: 0.8716
# Epoch 12: val_accuracy did not improve from 0.77307
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 414ms/step - accuracy: 0.6813 - loss: 0.8721 - val_accuracy: 0.7504 - val_loss: 0.7687 - learning_rate: 1.0000e-04
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6639 - loss: 0.9076
# Epoch 13: val_accuracy improved from 0.77307 to 0.78669, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 453ms/step - accuracy: 0.8185 - loss: 0.4805 - val_accuracy: 0.8457 - val_loss: 0.4162 - learning_rate: 1.0000e-04
# Epoch 39/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8120 - loss: 0.4893
# Epoch 39: val_accuracy did not improve from 0.86989
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 433ms/step - accuracy: 0.8120 - loss: 0.4894 - val_accuracy: 0.8517 - val_loss: 0.4006 - learning_rate: 1.0000e-04
# Epoch 40/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.7994 - loss: 0.5384
# Epoch 40: val_accuracy did not improve from 0.86989
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 414ms/step - accuracy: 0.7995 - loss: 0.5380 - val_accuracy: 0.8502 - val_loss: 0.4245 - learning_rate: 1.0000e-04
# Epoch 41/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8316 - loss: 0.4756
# Epoch 41: val_accuracy did not improve from 0.86989
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 37s 446ms/step - accuracy: 0.8316 - loss: 0.4757 - val_accuracy: 0.8366 - val_loss: 0.4426 - learning_rate: 1.0000e-04
# Epoch 42/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8117 - loss: 0.4979
# Epoch 42: val_accuracy did not improve from 0.86989
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 416ms/step - accuracy: 0.8116 - loss: 0.4980 - val_accuracy: 0.8502 - val_loss: 0.3866 - learning_rate: 1.0000e-04
# Epoch 43/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8304 - loss: 0.4718
# Epoch 43: val_accuracy improved from 0.86989 to 0.87141, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 485ms/step - accuracy: 0.8304 - loss: 0.4718 - val_accuracy: 0.8714 - val_loss: 0.3487 - learning_rate: 1.0000e-04
# Epoch 44/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8443 - loss: 0.4290
# Epoch 44: val_accuracy did not improve from 0.87141
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 459ms/step - accuracy: 0.8443 - loss: 0.4291 - val_accuracy: 0.8457 - val_loss: 0.4446 - learning_rate: 1.0000e-04
# Epoch 45/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8454 - loss: 0.4098
# Epoch 45: val_accuracy did not improve from 0.87141
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 413ms/step - accuracy: 0.8452 - loss: 0.4103 - val_accuracy: 0.8654 - val_loss: 0.3853 - learning_rate: 1.0000e-04
# Epoch 46/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8174 - loss: 0.4949
# Epoch 46: val_accuracy did not improve from 0.87141
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 37s 441ms/step - accuracy: 0.8174 - loss: 0.4948 - val_accuracy: 0.8638 - val_loss: 0.3763 - learning_rate: 1.0000e-04
# Epoch 47/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8466 - loss: 0.4210
# Epoch 47: val_accuracy did not improve from 0.87141
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 411ms/step - accuracy: 0.8466 - loss: 0.4210 - val_accuracy: 0.8699 - val_loss: 0.4048 - learning_rate: 1.0000e-04
# Epoch 48/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8354 - loss: 0.4446
# Epoch 48: val_accuracy did not improve from 0.87141
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 430ms/step - accuracy: 0.8355 - loss: 0.4443 - val_accuracy: 0.8714 - val_loss: 0.3691 - learning_rate: 1.0000e-04
# Epoch 49/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8466 - loss: 0.4448
# Epoch 49: val_accuracy improved from 0.87141 to 0.88048, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 532ms/step - accuracy: 0.8466 - loss: 0.4447 - val_accuracy: 0.8805 - val_loss: 0.3496 - learning_rate: 1.0000e-04
# Epoch 50/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8417 - loss: 0.4120
# Epoch 50: val_accuracy did not improve from 0.88048
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 37s 448ms/step - accuracy: 0.8415 - loss: 0.4122 - val_accuracy: 0.8790 - val_loss: 0.3285 - learning_rate: 1.0000e-04
#
# Unfreezing later VGG layers for fine-tuning...
#
# Fine-tuning model...
# Epoch 51/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8179 - loss: 0.5260
# Epoch 51: val_accuracy improved from 0.88048 to 0.88351, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 53s 283ms/step - accuracy: 0.8179 - loss: 0.5260 - val_accuracy: 0.8835 - val_loss: 0.3412 - learning_rate: 1.0000e-05
# Epoch 52/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8329 - loss: 0.4405
# Epoch 52: val_accuracy did not improve from 0.88351
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 261ms/step - accuracy: 0.8330 - loss: 0.4405 - val_accuracy: 0.8623 - val_loss: 0.3555 - learning_rate: 1.0000e-05
# Epoch 53/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8568 - loss: 0.4099
# Epoch 53: val_accuracy improved from 0.88351 to 0.88654, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 84s 273ms/step - accuracy: 0.8568 - loss: 0.4099 - val_accuracy: 0.8865 - val_loss: 0.3648 - learning_rate: 1.0000e-05
# Epoch 54/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8671 - loss: 0.3646
# Epoch 54: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 259ms/step - accuracy: 0.8671 - loss: 0.3648 - val_accuracy: 0.8744 - val_loss: 0.3834 - learning_rate: 1.0000e-05
# Epoch 55/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8824 - loss: 0.3406
# Epoch 55: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 225ms/step - accuracy: 0.8824 - loss: 0.3407 - val_accuracy: 0.8805 - val_loss: 0.3714 - learning_rate: 1.0000e-05
# Epoch 56/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8833 - loss: 0.3314
# Epoch 56: val_accuracy improved from 0.88654 to 0.89259, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 260ms/step - accuracy: 0.8833 - loss: 0.3315 - val_accuracy: 0.8926 - val_loss: 0.3372 - learning_rate: 1.0000e-05
# Epoch 57/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8683 - loss: 0.3489
# Epoch 57: val_accuracy improved from 0.89259 to 0.90166, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 47s 286ms/step - accuracy: 0.8683 - loss: 0.3490 - val_accuracy: 0.9017 - val_loss: 0.3382 - learning_rate: 1.0000e-05
# Epoch 58/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8820 - loss: 0.3076
# Epoch 58: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 258ms/step - accuracy: 0.8821 - loss: 0.3076 - val_accuracy: 0.8850 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 59/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8838 - loss: 0.3161
# Epoch 59: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 234ms/step - accuracy: 0.8838 - loss: 0.3162 - val_accuracy: 0.8865 - val_loss: 0.3395 - learning_rate: 1.0000e-05
# Epoch 60/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8988 - loss: 0.2775
# Epoch 60: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 225ms/step - accuracy: 0.8988 - loss: 0.2775 - val_accuracy: 0.8880 - val_loss: 0.3194 - learning_rate: 1.0000e-05
# Epoch 61/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8922 - loss: 0.2793
# Epoch 61: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 237ms/step - accuracy: 0.8922 - loss: 0.2794 - val_accuracy: 0.8684 - val_loss: 0.4252 - learning_rate: 1.0000e-05
# Epoch 62/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8901 - loss: 0.2897
# Epoch 62: val_accuracy improved from 0.90166 to 0.91377, saving model to /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 261ms/step - accuracy: 0.8901 - loss: 0.2898 - val_accuracy: 0.9138 - val_loss: 0.3066 - learning_rate: 1.0000e-05
# Epoch 63/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9003 - loss: 0.2962
# Epoch 63: val_accuracy did not improve from 0.91377
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - accuracy: 0.9003 - loss: 0.2963 - val_accuracy: 0.8533 - val_loss: 0.4605 - learning_rate: 1.0000e-05
# Epoch 64/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.
val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 236ms/step - accuracy: 0.9598 - loss: 0.1232 - val_accuracy: 0.9425 - val_loss: 0.2340 - learning_rate: 1.0000e-06
# Epoch 140/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9663 - loss: 0.1034
# Epoch 140: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 228ms/step - accuracy: 0.9663 - loss: 0.1034 - val_accuracy: 0.9304 - val_loss: 0.2512 - learning_rate: 1.0000e-06
# Epoch 141/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9669 - loss: 0.1014
# Epoch 141: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 38s 227ms/step - accuracy: 0.9669 - loss: 0.1014 - val_accuracy: 0.9304 - val_loss: 0.2597 - learning_rate: 1.0000e-06
# Epoch 142/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9636 - loss: 0.1135
# Epoch 142: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 235ms/step - accuracy: 0.9636 - loss: 0.1134 - val_accuracy: 0.9289 - val_loss: 0.2490 - learning_rate: 1.0000e-06
# Epoch 143/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9525 - loss: 0.1134
# Epoch 143: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 236ms/step - accuracy: 0.9526 - loss: 0.1133 - val_accuracy: 0.9259 - val_loss: 0.2576 - learning_rate: 1.0000e-06
# Epoch 144/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9668 - loss: 0.1115
# Epoch 144: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 226ms/step - accuracy: 0.9668 - loss: 0.1114 - val_accuracy: 0.9289 - val_loss: 0.2576 - learning_rate: 1.0000e-06
# Epoch 145/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9662 - loss: 0.1123
# Epoch 145: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 230ms/step - accuracy: 0.9662 - loss: 0.1123 - val_accuracy: 0.9380 - val_loss: 0.2434 - learning_rate: 1.0000e-06
# Epoch 146/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9616 - loss: 0.1255
# Epoch 146: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 236ms/step - accuracy: 0.9616 - loss: 0.1254 - val_accuracy: 0.9365 - val_loss: 0.2522 - learning_rate: 1.0000e-06
# Epoch 147/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9564 - loss: 0.1258
# Epoch 147: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 38s 228ms/step - accuracy: 0.9564 - loss: 0.1257 - val_accuracy: 0.9304 - val_loss: 0.2481 - learning_rate: 1.0000e-06
# Epoch 148/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9588 - loss: 0.1182
# Epoch 148: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 239ms/step - accuracy: 0.9588 - loss: 0.1181 - val_accuracy: 0.9440 - val_loss: 0.2320 - learning_rate: 1.0000e-06
# Epoch 149/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9666 - loss: 0.1007
# Epoch 149: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9666 - loss: 0.1008 - val_accuracy: 0.9380 - val_loss: 0.2321 - learning_rate: 1.0000e-06
# Epoch 150/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9720 - loss: 0.0894
# Epoch 150: val_accuracy did not improve from 0.94705
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 241ms/step - accuracy: 0.9720 - loss: 0.0895 - val_accuracy: 0.9410 - val_loss: 0.2325 - learning_rate: 1.0000e-06
#
# Loading the best model from /content/drive/MyDrive/KneeOA/best_vgg_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step
#
# Confusion Matrix:
# [[199   5   0   0   0]
#  [ 14 177   2   0   0]
#  [  0   8  82   1   2]
#  [  0   2   1  86   0]
#  [  0   0   0   0  82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      0Normal       0.93      0.98      0.95       204
#    1Doubtful       0.92      0.92      0.92       193
#        2Mild       0.96      0.88      0.92        93
#    3Moderate       0.99      0.97      0.98        89
#      4Severe       0.98      1.00      0.99        82
#
#     accuracy                           0.95       661
#    macro avg       0.96      0.95      0.95       661
# weighted avg       0.95      0.95      0.95       661
# Sample predictions on test set:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# The best model has been saved to: /content/drive/MyDrive/KneeOA/best_vgg_model.keras
