# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvani-5/KneeOA_DL/blob/main/Resnet50_KneeOA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you're using data from your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# Define class mapping
knee_classes = {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
class_names = list(knee_classes.keys())

# Enhanced data loader that combines both datasets
def load_combined_data(exp1_path, exp2_path, image_size=224):  # ResNet typically uses 224x224
    X, y = [], []

    # Load MedicalExpert-I
    print("Loading MedicalExpert-I...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp1_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    # Load MedicalExpert-II
    print("\nLoading MedicalExpert-II...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp2_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    return np.array(X), np.array(y)

# Paths to your datasets - UPDATE THESE
medical_expert_I_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-I"
medical_expert_II_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-II"

# Load combined data
X, y = load_combined_data(medical_expert_I_path, medical_expert_II_path)

# Check class distribution
print("\nClass distribution in combined dataset:")
for class_name, class_idx in knee_classes.items():
    print(f"{class_name}: {np.sum(y == class_idx)} samples")

# Convert to float32 and preprocess for ResNet50
X = X.astype('float32')
X = preprocess_input(X)  # Preprocess for ResNet50
y = to_categorical(y, num_classes=5)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print(f"\nTraining samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")

# Data augmentation for training set
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='constant',
    cval=0
)

# Build model using ResNet50
def build_resnet_model():
    base_model = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )

    # Freeze the base model layers first
    base_model.trainable = False

    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(5, activation='softmax')(x)

    model = Model(inputs, outputs)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model, base_model

model, base_model = build_resnet_model()
model.summary()

# Define the single best model path
best_model_path = '/content/drive/MyDrive/KneeOA/resnet_best_model.keras'

# Callbacks - THIS IS THE KEY PART
# ModelCheckpoint will save the model after each epoch if validation accuracy improves
callbacks = [
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=1e-6, verbose=1),
    ModelCheckpoint(
        filepath=best_model_path,
        monitor='val_accuracy',
        save_best_only=True,  # Only save when val_accuracy improves
        mode='max',
        verbose=1
    )
]

# First phase - train with frozen base model
print("\nTraining top layers with frozen ResNet50 base...")
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=32),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Unfreeze some layers for fine-tuning
print("\nUnfreezing later ResNet layers for fine-tuning...")
base_model.trainable = True
# Keep early blocks frozen
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("\nFine-tuning model...")
history_fine = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=16),
    epochs=150,
    initial_epoch=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,  # Same callback - will continue updating the same best model
    verbose=1
)

# Combine histories
combined_history = {}
for key in history.history:
    combined_history[key] = history.history[key] + history_fine.history[key]

# Load the best model for evaluation
print(f"\nLoading the best model from {best_model_path}")
best_model = load_model(best_model_path)

# Evaluate the best model
y_pred = np.argmax(best_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('/content/drive/MyDrive/KneeOA/resnet_confusion_matrix.png')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(combined_history['accuracy'], label='Train Accuracy')
plt.plot(combined_history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_history['loss'], label='Train Loss')
plt.plot(combined_history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/content/drive/MyDrive/KneeOA/resnet_training_history.png')
plt.show()

# Sample predictions
def predict_sample_images(model, X_test, y_test, num_samples=5):
    sample_indices = np.random.choice(len(X_test), num_samples, replace=False)

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(sample_indices, 1):
        image = X_test[idx]
        true_class = np.argmax(y_test[idx])

        # Make prediction
        pred_probs = model.predict(np.expand_dims(image, axis=0))
        pred_class = np.argmax(pred_probs)

        # Convert image back for display
        image = (image - image.min()) / (image.max() - image.min())  # Normalize to 0-1

        plt.subplot(1, num_samples, i)
        plt.imshow(image)
        plt.title(f"True: {class_names[true_class]}\nPred: {class_names[pred_class]}")
        plt.axis('off')

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/KneeOA/resnet_sample_predictions.png')
    plt.show()

# Display sample predictions
print("\nSample predictions on test set:")
predict_sample_images(best_model, X_test, y_test, num_samples=5)

print(f"\nThe best model has been saved to: {best_model_path}")
# Out:
# Loading MedicalExpert-I...
# Processing 0Normal... Loaded 514 samples
# Processing 1Doubtful... Loaded 477 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Loading MedicalExpert-II...
# Processing 0Normal... Loaded 504 samples
# Processing 1Doubtful... Loaded 488 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Class distribution in combined dataset:
# 0Normal: 1018 samples
# 1Doubtful: 965 samples
# 2Mild: 464 samples
# 3Moderate: 442 samples
# 4Severe: 412 samples
#
# Training samples: 2640
# Test samples: 661
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    51,380,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,104,133 (286.50 MB)
#  Trainable params: 51,514,885 (196.51 MB)
#  Non-trainable params: 23,589,248 (89.99 MB)
# Training top layers with frozen ResNet50 base...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.3145 - loss: 2.2450
# Epoch 1: val_accuracy improved from -inf to 0.58245, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 71s 651ms/step - accuracy: 0.3155 - loss: 2.2408 - val_accuracy: 0.5825 - val_loss: 1.4736 - learning_rate: 1.0000e-04
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4810 - loss: 1.5391
# Epoch 2: val_accuracy improved from 0.58245 to 0.66112, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 465ms/step - accuracy: 0.4810 - loss: 1.5386 - val_accuracy: 0.6611 - val_loss: 1.0882 - learning_rate: 1.0000e-04
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.5506 - loss: 1.3579
# Epoch 3: val_accuracy improved from 0.66112 to 0.70499, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 52s 624ms/step - accuracy: 0.5506 - loss: 1.3575 - val_accuracy: 0.7050 - val_loss: 0.8716 - learning_rate: 1.0000e-04
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.5649 - loss: 1.2768
# Epoch 4: val_accuracy did not improve from 0.70499
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 537ms/step - accuracy: 0.5649 - loss: 1.2767 - val_accuracy: 0.6899 - val_loss: 0.8622 - learning_rate: 1.0000e-04
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.6029 - loss: 1.1607
# Epoch 5: val_accuracy did not improve from 0.70499
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 432ms/step - accuracy: 0.6031 - loss: 1.1606 - val_accuracy: 0.6702 - val_loss: 0.8429 - learning_rate: 1.0000e-04
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6239 - loss: 1.0969
# Epoch 6: val_accuracy improved from 0.70499 to 0.72466, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 463ms/step - accuracy: 0.6239 - loss: 1.0970 - val_accuracy: 0.7247 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6402 - loss: 1.0286
# Epoch 7: val_accuracy did not improve from 0.72466
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 534ms/step - accuracy: 0.6402 - loss: 1.0288 - val_accuracy: 0.6838 - val_loss: 0.9250 - learning_rate: 1.0000e-04
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.6565 - loss: 0.9665
# Epoch 8: val_accuracy improved from 0.72466 to 0.73222, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 583ms/step - accuracy: 0.6565 - loss: 0.9665 - val_accuracy: 0.7322 - val_loss: 0.8048 - learning_rate: 1.0000e-04
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.6520 - loss: 1.0074
# Epoch 9: val_accuracy did not improve from 0.73222
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 391ms/step - accuracy: 0.6520 - loss: 1.0074 - val_accuracy: 0.6944 - val_loss: 0.9033 - learning_rate: 1.0000e-04
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6792 - loss: 0.8964
# Epoch 10: val_accuracy did not improve from 0.73222
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 367ms/step - accuracy: 0.6791 - loss: 0.8966 - val_accuracy: 0.7080 - val_loss: 0.7932 - learning_rate: 1.0000e-04
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.6869 - loss: 0.8813
# Epoch 11: val_accuracy improved from 0.73222 to 0.77005, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 513ms/step - accuracy: 0.6870 - loss: 0.8813 - val_accuracy: 0.7700 - val_loss: 0.5646 - learning_rate: 1.0000e-04
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.6916 - loss: 0.8663
# Epoch 12: val_accuracy did not improve from 0.77005
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 72s 386ms/step - accuracy: 0.6916 - loss: 0.8662 - val_accuracy: 0.7095 - val_loss: 0.7837 - learning_rate: 1.0000e-04
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7185 - loss: 0.8045
# Epoch 13: val_accuracy did not improve from 0.77005
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 375ms/step - accuracy: 0.7184 - loss: 0.8046 - val_accuracy: 0.7035 - val_loss: 0.8368 - learning_rate: 1.0000e-04
# Epoch 14/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.7101 - loss: 0.8181
# Epoch 14: val_accuracy improved from 0.77005 to 0.78669, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 611ms/step - accuracy: 0.7102 - loss: 0.8177 - val_accuracy: 0.7867 - val_loss: 0.5653 - learning_rate: 1.0000e-04
# Epoch 15/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7363 - loss: 0.7395
# Epoch 15: val_accuracy did not improve from 0.78669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 522ms/step - accuracy: 0.7362 - loss: 0.7398 - val_accuracy: 0.7625 - val_loss: 0.6275 - learning_rate: 1.0000e-04
# Epoch 16/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7272 - loss: 0.7699
# Epoch 16: val_accuracy improved from 0.78669 to 0.80182, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 525ms/step - accuracy: 0.7272 - loss: 0.7699 - val_accuracy: 0.8018 - val_loss: 0.5621 - learning_rate: 1.0000e-04
# Epoch 17/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7389 - loss: 0.7196
# Epoch 17: val_accuracy did not improve from 0.80182
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 535ms/step - accuracy: 0.7388 - loss: 0.7200 - val_accuracy: 0.7791 - val_loss: 0.5598 - learning_rate: 1.0000e-04
# Epoch 18/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.7334 - loss: 0.7464
# Epoch 18: val_accuracy did not improve from 0.80182
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 398ms/step - accuracy: 0.7334 - loss: 0.7464 - val_accuracy: 0.7352 - val_loss: 0.6428 - learning_rate: 1.0000e-04
# Epoch 19/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.7564 - loss: 0.6839
# Epoch 19: val_accuracy did not improve from 0.80182
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.7562 - loss: 0.6841 - val_accuracy: 0.7231 - val_loss: 0.7885 - learning_rate: 1.0000e-04
# Epoch 20/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7435 - loss: 0.7136
# Epoch 20: val_accuracy did not improve from 0.80182
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - accuracy: 0.7436 - loss: 0.7133 - val_accuracy: 0.7958 - val_loss: 0.5209 - learning_rate: 1.0000e-04
# Epoch 21/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7475 - loss: 0.7032
# Epoch 21: val_accuracy improved from 0.80182 to 0.82148, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 667ms/step - accuracy: 0.7475 - loss: 0.7033 - val_accuracy: 0.8215 - val_loss: 0.5065 - learning_rate: 1.0000e-04
# Epoch 22/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7553 - loss: 0.6520
# Epoch 22: val_accuracy did not improve from 0.82148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 524ms/step - accuracy: 0.7553 - loss: 0.6519 - val_accuracy: 0.7837 - val_loss: 0.5365 - learning_rate: 1.0000e-04
# Epoch 23/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.7663 - loss: 0.6185
# Epoch 23: val_accuracy did not improve from 0.82148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 395ms/step - accuracy: 0.7662 - loss: 0.6189 - val_accuracy: 0.7973 - val_loss: 0.5214 - learning_rate: 1.0000e-04
# Epoch 24/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.7681 - loss: 0.6114
# Epoch 24: val_accuracy did not improve from 0.82148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 364ms/step - accuracy: 0.7681 - loss: 0.6120 - val_accuracy: 0.7595 - val_loss: 0.6470 - learning_rate: 1.0000e-04
# Epoch 25/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7815 - loss: 0.5826
# Epoch 25: val_accuracy did not improve from 0.82148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 365ms/step - accuracy: 0.7814 - loss: 0.5828 - val_accuracy: 0.7746 - val_loss: 0.6213 - learning_rate: 1.0000e-04
# Epoch 26/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7660 - loss: 0.6107
# Epoch 26: val_accuracy did not improve from 0.82148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 375ms/step - accuracy: 0.7660 - loss: 0.6109 - val_accuracy: 0.8094 - val_loss: 0.5113 - learning_rate: 1.0000e-04
# Epoch 27/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0
50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8281 - loss: 0.4786
# Epoch 42: val_accuracy improved from 0.82148 to 0.82451, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 662ms/step - accuracy: 0.8280 - loss: 0.4786 - val_accuracy: 0.8245 - val_loss: 0.4873 - learning_rate: 1.0000e-05
# Epoch 43/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8122 - loss: 0.4970
# Epoch 43: val_accuracy did not improve from 0.82451
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 550ms/step - accuracy: 0.8123 - loss: 0.4969 - val_accuracy: 0.8215 - val_loss: 0.4764 - learning_rate: 1.0000e-05
# Epoch 44/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8092 - loss: 0.5012
# Epoch 44: val_accuracy did not improve from 0.82451
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 395ms/step - accuracy: 0.8093 - loss: 0.5012 - val_accuracy: 0.8185 - val_loss: 0.4718 - learning_rate: 1.0000e-05
# Epoch 45/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.8135 - loss: 0.5299
# Epoch 45: val_accuracy did not improve from 0.82451
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 405ms/step - accuracy: 0.8137 - loss: 0.5295 - val_accuracy: 0.8185 - val_loss: 0.4755 - learning_rate: 1.0000e-05
# Epoch 46/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.8408 - loss: 0.4267
# Epoch 46: val_accuracy did not improve from 0.82451
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 373ms/step - accuracy: 0.8407 - loss: 0.4270 - val_accuracy: 0.8215 - val_loss: 0.4891 - learning_rate: 1.0000e-05
# Epoch 47/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8194 - loss: 0.4585
# Epoch 47: val_accuracy did not improve from 0.82451
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 371ms/step - accuracy: 0.8196 - loss: 0.4584 - val_accuracy: 0.8230 - val_loss: 0.4751 - learning_rate: 1.0000e-05
# Epoch 48/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8300 - loss: 0.4550
# Epoch 48: val_accuracy improved from 0.82451 to 0.82905, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 587ms/step - accuracy: 0.8300 - loss: 0.4551 - val_accuracy: 0.8290 - val_loss: 0.4603 - learning_rate: 1.0000e-05
# Epoch 49/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8243 - loss: 0.4769
# Epoch 49: val_accuracy improved from 0.82905 to 0.83207, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 67s 809ms/step - accuracy: 0.8244 - loss: 0.4768 - val_accuracy: 0.8321 - val_loss: 0.4490 - learning_rate: 1.0000e-05
# Epoch 50/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.8376 - loss: 0.4291
# Epoch 50: val_accuracy improved from 0.83207 to 0.83359, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 68s 820ms/step - accuracy: 0.8375 - loss: 0.4293 - val_accuracy: 0.8336 - val_loss: 0.4510 - learning_rate: 1.0000e-05
#
# Unfreezing later ResNet layers for fine-tuning...
#
# Fine-tuning model...
# Epoch 51/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6877 - loss: 0.9987
# Epoch 51: val_accuracy did not improve from 0.83359
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 96s 317ms/step - accuracy: 0.6878 - loss: 0.9981 - val_accuracy: 0.7685 - val_loss: 0.9274 - learning_rate: 1.0000e-05
# Epoch 52/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7616 - loss: 0.7280
# Epoch 52: val_accuracy did not improve from 0.83359
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 226ms/step - accuracy: 0.7616 - loss: 0.7280 - val_accuracy: 0.8048 - val_loss: 0.6721 - learning_rate: 1.0000e-05
# Epoch 53/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7904 - loss: 0.5943
# Epoch 53: val_accuracy did not improve from 0.83359
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 222ms/step - accuracy: 0.7904 - loss: 0.5945 - val_accuracy: 0.8260 - val_loss: 0.5976 - learning_rate: 1.0000e-05
# Epoch 54/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8076 - loss: 0.5726
# Epoch 54: val_accuracy improved from 0.83359 to 0.83510, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 265ms/step - accuracy: 0.8075 - loss: 0.5728 - val_accuracy: 0.8351 - val_loss: 0.5532 - learning_rate: 1.0000e-05
# Epoch 55/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.8091 - loss: 0.5731
# Epoch 55: val_accuracy improved from 0.83510 to 0.83661, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 57s 348ms/step - accuracy: 0.8091 - loss: 0.5731 - val_accuracy: 0.8366 - val_loss: 0.5063 - learning_rate: 1.0000e-05
# Epoch 56/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.8106 - loss: 0.5189
# Epoch 56: val_accuracy improved from 0.83661 to 0.85023, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 70s 427ms/step - accuracy: 0.8106 - loss: 0.5189 - val_accuracy: 0.8502 - val_loss: 0.4418 - learning_rate: 1.0000e-05
# Epoch 57/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8345 - loss: 0.4877
# Epoch 57: val_accuracy improved from 0.85023 to 0.87141, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 63s 383ms/step - accuracy: 0.8344 - loss: 0.4878 - val_accuracy: 0.8714 - val_loss: 0.4350 - learning_rate: 1.0000e-05
# Epoch 58/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.8225 - loss: 0.5118
# Epoch 58: val_accuracy improved from 0.87141 to 0.87292, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 68s 414ms/step - accuracy: 0.8225 - loss: 0.5115 - val_accuracy: 0.8729 - val_loss: 0.4014 - learning_rate: 1.0000e-05
# Epoch 59/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.8534 - loss: 0.4336
# Epoch 59: val_accuracy improved from 0.87292 to 0.89259, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 78s 472ms/step - accuracy: 0.8533 - loss: 0.4337 - val_accuracy: 0.8926 - val_loss: 0.3365 - learning_rate: 1.0000e-05
# Epoch 60/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.8479 - loss: 0.4282
# Epoch 60: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.8480 - loss: 0.4281 - val_accuracy: 0.8790 - val_loss: 0.3401 - learning_rate: 1.0000e-05
# Epoch 61/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8603 - loss: 0.3955
# Epoch 61: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 266ms/step - accuracy: 0.8603 - loss: 0.3955 - val_accuracy: 0.8850 - val_loss: 0.3210 - learning_rate: 1.0000e-05
# Epoch 62/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8657 - loss: 0.3809
# Epoch 62: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 220ms/step - accuracy: 0.8656 - loss: 0.3809 - val_accuracy: 0.8835 - val_loss: 0.3377 - learning_rate: 1.0000e-05
# Epoch 63/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8688 - loss: 0.3629
# Epoch 63: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 220ms/step - accuracy: 0.8689 - loss: 0.3629 - val_accuracy: 0.8926 - val_loss: 0.3268 - learning_rate: 1.0000e-05
# Epoch 64/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8808 - loss: 0.3463
# Epoch 64: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.8808 - loss: 0.3462 - val_accuracy: 0.8608 - val_loss: 0.3712 - learning_rate: 1.0000e-05
# Epoch 65/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8815 - loss: 0.3379
# Epoch 65: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 221ms/step - accuracy: 0.8815 - loss: 0.3377 - val_accuracy: 0.8805 - val_loss: 0.3164 - learning_rate: 1.0000e-05
# Epoch 66/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8996 - loss: 0.2745
# Epoch 66: val_accuracy did not improve from 0.89259
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 35s 213ms/step - accuracy: 0.8996 - loss: 0.2746 - val_accuracy: 0.8805 - val_loss: 0.3428 - learning_rate: 1.0000e-05
# Epoch 67/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8964 - loss: 0.2818
# Epoch 67: val_accuracy improved from 0.89259 to 0.89713, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 58s 352ms/step - accuracy: 0.8964 - loss: 0.2819 - val_accuracy: 0.8971 - val_loss: 0.2724 - learning_rate: 1.0000e-05
# Epoch 68/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.8953 - loss: 0.2778
# Epoch 68: val_accuracy improved from 0.89713 to 0.90923, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 58s 351ms/step - accuracy: 0.8953 - loss: 0.2779 - val_accuracy: 0.9092 - val_loss: 0.2608 - learning_rate: 1.0000e-05
# Epoch 69/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9120 - loss: 0.2680
# Epoch 69: val_accuracy did not improve from 0.90923
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 66s 254ms/step - accuracy: 0.9120 - loss: 0.2680 - val_accuracy: 0.8971 - val_loss: 0.2944 - learning_rate: 1.0000e-05
# Epoch 70/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8893 - loss: 0.2963
# Epoch 70: val_accuracy did not improve from 0.90923
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 239ms/step - accuracy: 0.8894 - loss: 0.2961 - val_accuracy: 0.8896 - val_loss: 0.2947 - learning_rate: 1.0000e-05
# Epoch 71/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9170 - loss: 0.2225
# Epoch 71: val_accuracy did not improve from 0.90923
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 225ms/step - accuracy: 0.9170 - loss: 0.2227 - val_accuracy: 0.9062 - val_loss: 0.2800 - learning_rate: 1.0000e-05
# Epoch 72/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9046 - loss: 0.2495
# Epoch 72: val_accuracy did not improve from 0.90923
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 224ms/step - accuracy: 0.9046 - loss: 0.2495 - val_accuracy: 0.8850 - val_loss: 0.3652 - learning_rate: 1.0000e-05
# Epoch 73/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9275 - loss: 0.2143
# Epoch 73: val_accuracy did not improve from 0.90923
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 35s 214ms/step - accuracy: 0.9274 - loss: 0.2145 - val_accuracy: 0.9077 - val_loss: 0.2757 - learning_rate: 1.0000e-05
# Epoch 74/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9088 - loss: 0.2708
# Epoch 74: val_accuracy improved from 0.90923 to 0.91074, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 63s 345ms/step - accuracy: 0.9088 - loss: 0.2708 - val_accuracy: 0.9107 - val_loss: 0.2604 - learning_rate: 1.0000e-05
# Epoch 75/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9253 - loss: 0.2107
# Epoch 75: val_accuracy improved from 0.91074 to 0.92133, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 70s 422ms/step - accuracy: 0.9253 - loss: 0.2108 - val_accuracy: 0.9213 - val_loss: 0.2493 - learning_rate: 1.0000e-05
# Epoch 76/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9133 - loss: 0.2327
# Epoch 76: val_accuracy did not improve from 0.92133
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 48s 291ms/step - accuracy: 0.9134 - loss: 0.2327 - val_accuracy: 0.9138 - val_loss: 0.2858 - learning_rate: 1.0000e-05
# Epoch 77/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9252 - loss: 0.2216
# Epoch 77: val_accuracy did not improve from 0.92133
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 260ms/step - accuracy: 0.9253 - loss: 0.2215 - val_accuracy: 0.8956 - val_loss: 0.3423 - learning_rate: 1.0000e-05
# Epoch 78/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9259 - loss: 0.1977
# Epoch 78: val_accuracy did not improve from 0.92133
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 221ms/step - accuracy: 0.9259 - loss: 0.1977 - val_accuracy: 0.9047 - val_loss: 0.3139 - learning_rate: 1.0000e-05
# Epoch 79/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9318 - loss: 0.1982
# Epoch 79: val_accuracy did not improve from 0.92133
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 219ms/step - accuracy: 0.9318 - loss: 0.1983 - val_accuracy: 0.9062 - val_loss: 0.2899 - learning_rate: 1.0000e-05
# Epoch 80/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9420 - loss: 0.1798
# Epoch 80: val_accuracy did not improve from 0.92133
# 165/165 ━━━━━━━━━━━━━━━━━━━━
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9546 - loss: 0.1433 - val_accuracy: 0.9244 - val_loss: 0.2320 - learning_rate: 1.0000e-06
# Epoch 96/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9599 - loss: 0.1193
# Epoch 96: val_accuracy improved from 0.92436 to 0.92890, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 67s 379ms/step - accuracy: 0.9599 - loss: 0.1194 - val_accuracy: 0.9289 - val_loss: 0.2381 - learning_rate: 1.0000e-06
# Epoch 97/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9553 - loss: 0.1398
# Epoch 97: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 49s 297ms/step - accuracy: 0.9553 - loss: 0.1397 - val_accuracy: 0.9259 - val_loss: 0.2349 - learning_rate: 1.0000e-06
# Epoch 98/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9455 - loss: 0.1567
# Epoch 98: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 70s 223ms/step - accuracy: 0.9455 - loss: 0.1566 - val_accuracy: 0.9259 - val_loss: 0.2371 - learning_rate: 1.0000e-06
# Epoch 99/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9599 - loss: 0.1292
# Epoch 99: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 222ms/step - accuracy: 0.9599 - loss: 0.1293 - val_accuracy: 0.9274 - val_loss: 0.2282 - learning_rate: 1.0000e-06
# Epoch 100/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9582 - loss: 0.1218
# Epoch 100: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 219ms/step - accuracy: 0.9582 - loss: 0.1219 - val_accuracy: 0.9289 - val_loss: 0.2277 - learning_rate: 1.0000e-06
# Epoch 101/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9567 - loss: 0.1323
# Epoch 101: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 35s 213ms/step - accuracy: 0.9567 - loss: 0.1322 - val_accuracy: 0.9228 - val_loss: 0.2305 - learning_rate: 1.0000e-06
# Epoch 102/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9490 - loss: 0.1307
# Epoch 102: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 218ms/step - accuracy: 0.9490 - loss: 0.1308 - val_accuracy: 0.9228 - val_loss: 0.2292 - learning_rate: 1.0000e-06
# Epoch 103/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9606 - loss: 0.1282
# Epoch 103: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9606 - loss: 0.1283 - val_accuracy: 0.9259 - val_loss: 0.2365 - learning_rate: 1.0000e-06
# Epoch 104/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9547 - loss: 0.1308
# Epoch 104: val_accuracy did not improve from 0.92890
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 217ms/step - accuracy: 0.9547 - loss: 0.1309 - val_accuracy: 0.9289 - val_loss: 0.2396 - learning_rate: 1.0000e-06
# Epoch 105/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9592 - loss: 0.1245
# Epoch 105: val_accuracy improved from 0.92890 to 0.93343, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 71s 402ms/step - accuracy: 0.9592 - loss: 0.1246 - val_accuracy: 0.9334 - val_loss: 0.2344 - learning_rate: 1.0000e-06
# Epoch 106/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9607 - loss: 0.1075
# Epoch 106: val_accuracy did not improve from 0.93343
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.9607 - loss: 0.1075 - val_accuracy: 0.9319 - val_loss: 0.2213 - learning_rate: 1.0000e-06
# Epoch 107/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9583 - loss: 0.1138
# Epoch 107: val_accuracy improved from 0.93343 to 0.93495, saving model to /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 59s 355ms/step - accuracy: 0.9583 - loss: 0.1138 - val_accuracy: 0.9349 - val_loss: 0.2216 - learning_rate: 1.0000e-06
# Epoch 108/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9594 - loss: 0.1210
# Epoch 108: val_accuracy did not improve from 0.93495
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 66s 257ms/step - accuracy: 0.9594 - loss: 0.1210 - val_accuracy: 0.9349 - val_loss: 0.2176 - learning_rate: 1.0000e-06
# Epoch 109/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.
val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 35s 214ms/step - accuracy: 0.9604 - loss: 0.1205 - val_accuracy: 0.9274 - val_loss: 0.2296 - learning_rate: 1.0000e-06
# Epoch 140/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9583 - loss: 0.1328
# Epoch 140: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 214ms/step - accuracy: 0.9583 - loss: 0.1327 - val_accuracy: 0.9274 - val_loss: 0.2263 - learning_rate: 1.0000e-06
# Epoch 141/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9695 - loss: 0.0998
# Epoch 141: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 222ms/step - accuracy: 0.9695 - loss: 0.0998 - val_accuracy: 0.9274 - val_loss: 0.2361 - learning_rate: 1.0000e-06
# Epoch 142/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9674 - loss: 0.1063
# Epoch 142: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 224ms/step - accuracy: 0.9674 - loss: 0.1062 - val_accuracy: 0.9289 - val_loss: 0.2356 - learning_rate: 1.0000e-06
# Epoch 143/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9650 - loss: 0.1159
# Epoch 143: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 224ms/step - accuracy: 0.9650 - loss: 0.1159 - val_accuracy: 0.9274 - val_loss: 0.2372 - learning_rate: 1.0000e-06
# Epoch 144/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9645 - loss: 0.0999
# Epoch 144: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.9645 - loss: 0.0999 - val_accuracy: 0.9304 - val_loss: 0.2258 - learning_rate: 1.0000e-06
# Epoch 145/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9653 - loss: 0.0999
# Epoch 145: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 224ms/step - accuracy: 0.9653 - loss: 0.0999 - val_accuracy: 0.9274 - val_loss: 0.2213 - learning_rate: 1.0000e-06
# Epoch 146/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9631 - loss: 0.1079
# Epoch 146: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 223ms/step - accuracy: 0.9631 - loss: 0.1078 - val_accuracy: 0.9274 - val_loss: 0.2250 - learning_rate: 1.0000e-06
# Epoch 147/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9630 - loss: 0.1179
# Epoch 147: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 218ms/step - accuracy: 0.9630 - loss: 0.1178 - val_accuracy: 0.9289 - val_loss: 0.2279 - learning_rate: 1.0000e-06
# Epoch 148/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9656 - loss: 0.1086
# Epoch 148: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 219ms/step - accuracy: 0.9656 - loss: 0.1085 - val_accuracy: 0.9304 - val_loss: 0.2261 - learning_rate: 1.0000e-06
# Epoch 149/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9616 - loss: 0.1120
# Epoch 149: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 226ms/step - accuracy: 0.9615 - loss: 0.1120 - val_accuracy: 0.9304 - val_loss: 0.2205 - learning_rate: 1.0000e-06
# Epoch 150/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9493 - loss: 0.1345
# Epoch 150: val_accuracy did not improve from 0.93646
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 36s 220ms/step - accuracy: 0.9494 - loss: 0.1345 - val_accuracy: 0.9304 - val_loss: 0.2196 - learning_rate: 1.0000e-06
#
# Loading the best model from /content/drive/MyDrive/KneeOA/resnet_best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step
#
# Confusion Matrix:
# [[197   7   0   0   0]
#  [ 15 170   6   0   2]
#  [  4   2  81   3   3]
#  [  0   0   0  89   0]
#  [  0   0   0   0  82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      0Normal       0.91      0.97      0.94       204
#    1Doubtful       0.95      0.88      0.91       193
#        2Mild       0.93      0.87      0.90        93
#    3Moderate       0.97      1.00      0.98        89
#      4Severe       0.94      1.00      0.97        82
#
#     accuracy                           0.94       661
#    macro avg       0.94      0.94      0.94       661
# weighted avg       0.94      0.94      0.94       661
# Sample predictions on test set:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# The best model has been saved to: /content/drive/MyDrive/KneeOA/resnet_best_model.keras
