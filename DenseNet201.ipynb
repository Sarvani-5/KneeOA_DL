# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvani-5/KneeOA_DL/blob/main/DenseNet201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet201, preprocess_input

# Define class mapping
knee_classes = {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
class_names = list(knee_classes.keys())

# Enhanced data loader that combines both datasets
def load_combined_data(exp1_path, exp2_path, image_size=224):  # DenseNet typically uses 224x224
    X, y = [], []

    # Load MedicalExpert-I
    print("Loading MedicalExpert-I...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp1_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    # Load MedicalExpert-II
    print("\nLoading MedicalExpert-II...")
    for class_name, class_idx in knee_classes.items():
        class_path = os.path.join(exp2_path, class_name)
        if not os.path.exists(class_path):
            print(f"Warning: Missing directory {class_path}")
            continue

        print(f"Processing {class_name}...", end=' ')
        count = 0
        for img_name in os.listdir(class_path):
            try:
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue

                img = cv2.resize(img, (image_size, image_size))
                # Convert grayscale to RGB by repeating the channel
                img_rgb = cv2.merge([img, img, img])
                X.append(img_rgb)
                y.append(class_idx)
                count += 1
            except Exception as e:
                print(f"Error processing {img_path}: {str(e)}")
        print(f"Loaded {count} samples")

    return np.array(X), np.array(y)

# Paths to your datasets - UPDATE THESE
medical_expert_I_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-I"
medical_expert_II_path = "/content/drive/MyDrive/KneeOA/MedicalExpert-II"

# Load combined data
X, y = load_combined_data(medical_expert_I_path, medical_expert_II_path)

# Check class distribution
print("\nClass distribution in combined dataset:")
for class_name, class_idx in knee_classes.items():
    print(f"{class_name}: {np.sum(y == class_idx)} samples")

# Convert to float32 and preprocess for DenseNet201
X = X.astype('float32')
X = preprocess_input(X)  # Preprocess for DenseNet201
y = to_categorical(y, num_classes=5)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print(f"\nTraining samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")

# Data augmentation for training set
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='constant',
    cval=0
)

# Build model using DenseNet201
def build_densenet_model():
    base_model = DenseNet201(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )

    # Freeze the base model layers first
    base_model.trainable = False

    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(5, activation='softmax')(x)

    model = Model(inputs, outputs)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model, base_model

model, base_model = build_densenet_model()
model.summary()

# Define the single best model path
best_model_path = '/content/drive/MyDrive/KneeOA/densenet201_best_model.keras'

# Callbacks
callbacks = [
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=1e-6, verbose=1),
    ModelCheckpoint(
        filepath=best_model_path,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

# First phase - train with frozen base model
print("\nTraining top layers with frozen DenseNet201 base...")
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=32),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Unfreeze some layers for fine-tuning
print("\nUnfreezing later DenseNet201 layers for fine-tuning...")
base_model.trainable = True
# DenseNet201 has a different architecture - freeze early layers
# DenseNet201 has 4 dense blocks, we'll keep the first two frozen
# Approach: freeze approximately the first half of the network
num_layers = len(base_model.layers)
for layer in base_model.layers[:int(num_layers/2)]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("\nFine-tuning model...")
history_fine = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=16),
    epochs=150,
    initial_epoch=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Combine histories
combined_history = {}
for key in history.history:
    combined_history[key] = history.history[key] + history_fine.history[key]

# Load the best model for evaluation
print(f"\nLoading the best model from {best_model_path}")
best_model = load_model(best_model_path)

# Evaluate the best model
y_pred = np.argmax(best_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('/content/drive/MyDrive/KneeOA/densenet201_confusion_matrix.png')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(combined_history['accuracy'], label='Train Accuracy')
plt.plot(combined_history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_history['loss'], label='Train Loss')
plt.plot(combined_history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/content/drive/MyDrive/KneeOA/densenet201_training_history.png')
plt.show()

# Sample predictions
def predict_sample_images(model, X_test, y_test, num_samples=5):
    sample_indices = np.random.choice(len(X_test), num_samples, replace=False)

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(sample_indices, 1):
        image = X_test[idx]
        true_class = np.argmax(y_test[idx])

        # Make prediction
        pred_probs = model.predict(np.expand_dims(image, axis=0))
        pred_class = np.argmax(pred_probs)

        # Convert image back for display
        image = (image - image.min()) / (image.max() - image.min())  # Normalize to 0-1

        plt.subplot(1, num_samples, i)
        plt.imshow(image)
        plt.title(f"True: {class_names[true_class]}\nPred: {class_names[pred_class]}")
        plt.axis('off')

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/KneeOA/densenet201_sample_predictions.png')
    plt.show()

# Display sample predictions
print("\nSample predictions on test set:")
predict_sample_images(best_model, X_test, y_test, num_samples=5)

print(f"\nThe best model has been saved to: {best_model_path}")
# Out:
# Loading MedicalExpert-I...
# Processing 0Normal... Loaded 514 samples
# Processing 1Doubtful... Loaded 477 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Loading MedicalExpert-II...
# Processing 0Normal... Loaded 504 samples
# Processing 1Doubtful... Loaded 488 samples
# Processing 2Mild... Loaded 232 samples
# Processing 3Moderate... Loaded 221 samples
# Processing 4Severe... Loaded 206 samples
#
# Class distribution in combined dataset:
# 0Normal: 1018 samples
# 1Doubtful: 965 samples
# 2Mild: 464 samples
# 3Moderate: 442 samples
# 4Severe: 412 samples
#
# Training samples: 2640
# Test samples: 661
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 7, 7, 1920)     │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 94080)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    48,169,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,627,141 (254.16 MB)
#  Trainable params: 48,303,621 (184.26 MB)
#  Non-trainable params: 18,323,520 (69.90 MB)
# Training top layers with frozen DenseNet201 base...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.3521 - loss: 2.1675
# Epoch 1: val_accuracy improved from -inf to 0.41755, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.3528 - loss: 2.1639 - val_accuracy: 0.4175 - val_loss: 1.7428 - learning_rate: 1.0000e-04
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.5021 - loss: 1.4454
# Epoch 2: val_accuracy improved from 0.41755 to 0.66415, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 515ms/step - accuracy: 0.5022 - loss: 1.4452 - val_accuracy: 0.6641 - val_loss: 0.8983 - learning_rate: 1.0000e-04
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.5457 - loss: 1.2959
# Epoch 3: val_accuracy improved from 0.66415 to 0.69743, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.5457 - loss: 1.2958 - val_accuracy: 0.6974 - val_loss: 0.8345 - learning_rate: 1.0000e-04
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.5989 - loss: 1.1262
# Epoch 4: val_accuracy improved from 0.69743 to 0.70802, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 619ms/step - accuracy: 0.5990 - loss: 1.1265 - val_accuracy: 0.7080 - val_loss: 0.7998 - learning_rate: 1.0000e-04
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6092 - loss: 1.1205
# Epoch 5: val_accuracy did not improve from 0.70802
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 415ms/step - accuracy: 0.6092 - loss: 1.1206 - val_accuracy: 0.6884 - val_loss: 0.8222 - learning_rate: 1.0000e-04
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6298 - loss: 1.0415
# Epoch 6: val_accuracy improved from 0.70802 to 0.71710, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 556ms/step - accuracy: 0.6298 - loss: 1.0417 - val_accuracy: 0.7171 - val_loss: 0.7552 - learning_rate: 1.0000e-04
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.6207 - loss: 1.0691
# Epoch 7: val_accuracy did not improve from 0.71710
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 396ms/step - accuracy: 0.6210 - loss: 1.0684 - val_accuracy: 0.6732 - val_loss: 0.9030 - learning_rate: 1.0000e-04
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.6833 - loss: 0.9536
# Epoch 8: val_accuracy improved from 0.71710 to 0.72920, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 542ms/step - accuracy: 0.6832 - loss: 0.9537 - val_accuracy: 0.7292 - val_loss: 0.7087 - learning_rate: 1.0000e-04
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.6550 - loss: 0.9669
# Epoch 9: val_accuracy did not improve from 0.72920
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 524ms/step - accuracy: 0.6551 - loss: 0.9665 - val_accuracy: 0.7020 - val_loss: 0.7920 - learning_rate: 1.0000e-04
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6744 - loss: 0.9130
# Epoch 10: val_accuracy did not improve from 0.72920
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 403ms/step - accuracy: 0.6746 - loss: 0.9128 - val_accuracy: 0.7095 - val_loss: 0.7795 - learning_rate: 1.0000e-04
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.6990 - loss: 0.8745
# Epoch 11: val_accuracy improved from 0.72920 to 0.73222, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 496ms/step - accuracy: 0.6990 - loss: 0.8745 - val_accuracy: 0.7322 - val_loss: 0.7292 - learning_rate: 1.0000e-04
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7089 - loss: 0.8267
# Epoch 12: val_accuracy improved from 0.73222 to 0.73374, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 783ms/step - accuracy: 0.7088 - loss: 0.8269 - val_accuracy: 0.7337 - val_loss: 0.7185 - learning_rate: 1.0000e-04
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.6818 - loss: 0.8693
# Epoch 13: val_accuracy improved from 0.73374 to 0.75946, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 841ms/step - accuracy: 0.6819 - loss: 0.8690 - val_accuracy: 0.7595 - val_loss: 0.6510 - learning_rate: 1.0000e-04
# Epoch 14/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7242 - loss: 0.8045
# Epoch 14: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 561ms/step - accuracy: 0.7243 - loss: 0.8042 - val_accuracy: 0.7141 - val_loss: 0.7045 - learning_rate: 1.0000e-04
# Epoch 15/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.7212 - loss: 0.7815
# Epoch 15: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.7211 - loss: 0.7816 - val_accuracy: 0.7504 - val_loss: 0.6328 - learning_rate: 1.0000e-04
# Epoch 16/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7078 - loss: 0.7944
# Epoch 16: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 392ms/step - accuracy: 0.7078 - loss: 0.7944 - val_accuracy: 0.7141 - val_loss: 0.8168 - learning_rate: 1.0000e-04
# Epoch 17/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.7275 - loss: 0.7568
# Epoch 17: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 403ms/step - accuracy: 0.7276 - loss: 0.7565 - val_accuracy: 0.7020 - val_loss: 0.7741 - learning_rate: 1.0000e-04
# Epoch 18/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7298 - loss: 0.7502
# Epoch 18: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 389ms/step - accuracy: 0.7300 - loss: 0.7499 - val_accuracy: 0.7186 - val_loss: 0.7077 - learning_rate: 1.0000e-04
# Epoch 19/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7482 - loss: 0.6924
# Epoch 19: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 422ms/step - accuracy: 0.7482 - loss: 0.6926 - val_accuracy: 0.7413 - val_loss: 0.6853 - learning_rate: 1.0000e-04
# Epoch 20/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.7464 - loss: 0.7277
# Epoch 20: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 393ms/step - accuracy: 0.7464 - loss: 0.7275 - val_accuracy: 0.7368 - val_loss: 0.6398 - learning_rate: 1.0000e-04
# Epoch 21/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.7559 - loss: 0.6924
# Epoch 21: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 398ms/step - accuracy: 0.7559 - loss: 0.6923 - val_accuracy: 0.7292 - val_loss: 0.6290 - learning_rate: 1.0000e-04
# Epoch 22/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7520 - loss: 0.6850
# Epoch 22: val_accuracy did not improve from 0.75946
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 387ms/step - accuracy: 0.7521 - loss: 0.6848 - val_accuracy: 0.7428 - val_loss: 0.6719 - learning_rate: 1.0000e-04
# Epoch 23/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7417 - loss: 0.7038
# Epoch 23: val_accuracy improved from 0.75946 to 0.76551, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 592ms/step - accuracy: 0.7419 - loss: 0.7034 - val_accuracy: 0.7655 - val_loss: 0.5689 - learning_rate: 1.0000e-04
# Epoch 24/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7718 - loss: 0.6655
# Epoch 24: val_accuracy improved from 0.76551 to 0.77761, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 793ms/step - accuracy: 0.7717 - loss: 0.6654 - val_accuracy: 0.7776 - val_loss: 0.5677 - learning_rate: 1.0000e-04
# Epoch 25/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7612 - loss: 0.6510
# Epoch 25: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 524ms/step - accuracy: 0.7613 - loss: 0.6506 - val_accuracy: 0.7595 - val_loss: 0.5908 - learning_rate: 1.0000e-04
# Epoch 26/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.7891 - loss: 0.6051
# Epoch 26: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 405ms/step - accuracy: 0.7890 - loss: 0.6053 - val_accuracy: 0.7398 - val_loss: 0.6537 - learning_rate: 1.0000e-04
# Epoch 27/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.7810 - loss: 0.6203
# Epoch 27: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 395ms/step - accuracy: 0.7810 - loss: 0.6201 - val_accuracy: 0.7655 - val_loss: 0.6244 - learning_rate: 1.0000e-04
# Epoch 28/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7729 - loss: 0.6182
# Epoch 28: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 390ms/step - accuracy: 0.7729 - loss: 0.6180 - val_accuracy: 0.7640 - val_loss: 0.5614 - learning_rate: 1.0000e-04
# Epoch 29/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7967 - loss: 0.5603
# Epoch 29: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 390ms/step - accuracy: 0.7966 - loss: 0.5606 - val_accuracy: 0.7277 - val_loss: 0.7489 - learning_rate: 1.0000e-04
# Epoch 30/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.7922 - loss: 0.5495
# Epoch 30: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 398ms/step - accuracy: 0.7922 - loss: 0.5499 - val_accuracy: 0.7262 - val_loss: 0.7137 - learning_rate: 1.0000e-04
# Epoch 31/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7857 - loss: 0.5783
# Epoch 31: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 387ms/step - accuracy: 0.7858 - loss: 0.5782 - val_accuracy: 0.7746 - val_loss: 0.5392 - learning_rate: 1.0000e-04
# Epoch 32/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7868 - loss: 0.5725
# Epoch 32: val_accuracy did not improve from 0.77761
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 390ms/step - accuracy: 0.7868 - loss: 0.5729 - val_accuracy: 0.7716 - val_loss: 0.5547 - learning_rate: 1.0000e-04
# Epoch 33/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8006 - loss: 0.5269
# Epoch 33: val_accuracy improved from 0.77761 to 0.78366, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 68s 720ms/step - accuracy: 0.8006 - loss: 0.5272 - val_accuracy: 0.7837 - val_loss: 0.5676 - learning_rate: 1.0000e-04
# Epoch 34/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.7910 - loss: 0.5937
# Epoch 34: val_accuracy did not improve from 0.78366
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 526ms/step - accuracy: 0.7910 - loss: 0.5935 - val_accuracy: 0.7655 - val_loss: 0.6538 - learning_rate: 1.0000e-04
# Epoch 35/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.7962 - loss: 0.5728
# Epoch 35: val_accuracy did not improve from 0.78366
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 37s 441ms/step - accuracy: 0.7962 - loss: 0.5726 - val_accuracy: 0.7806 - val_loss: 0.5586 - learning_rate: 1.0000e-04
# Epoch 36/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.7975 - loss: 0.5442
# Epoch 36: val_accuracy did not improve from 0.78366
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 393ms/step - accuracy: 0.7976 - loss: 0.5443 - val_accuracy: 0.7837 - val_loss: 0.5596 - learning_rate: 1.0000e-04
# Epoch 37/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.7986 - loss: 0.5269
# Epoch 37: val_accuracy improved from 0.78366 to 0.78517, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 698ms/step - accuracy: 0.7986 - loss: 0.5270 - val_accuracy: 0.7852 - val_loss: 0.4849 - learning_rate: 1.0000e-04
# Epoch 38/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.8118 - loss: 0.5069
# Epoch 38: val_accuracy did not improve from 0.78517
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.8117 - loss: 0.5071 - val_accuracy: 0.7776 - val_loss: 0.5198 - learning_rate: 1.0000e-04
# Epoch 39/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8025 - loss: 0.5289
# Epoch 39: val_accuracy did not improve from 0.78517
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 411ms/step - accuracy: 0.8026 - loss: 0.5288 - val_accuracy: 0.7716 - val_loss: 0.5552 - learning_rate: 1.0000e-04
# Epoch 40/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8169 - loss: 0.4727
# Epoch 40: val_accuracy did not improve from 0.78517
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 392ms/step - accuracy: 0.8169 - loss: 0.4730 - val_accuracy: 0.7564 - val_loss: 0.5706 - learning_rate: 1.0000e-04
# Epoch 41/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8091 - loss: 0.5157
# Epoch 41: val_accuracy did not improve from 0.78517
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 423ms/step - accuracy: 0.8090 - loss: 0.5157 - val_accuracy: 0.7806 - val_loss: 0.5211 - learning_rate: 1.0000e-04
# Epoch 42/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.8165 - loss: 0.4977
# Epoch 42: val_accuracy improved from 0.78517 to 0.79576, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 705ms/step - accuracy: 0.8164 - loss: 0.4979 - val_accuracy: 0.7958 - val_loss: 0.5050 - learning_rate: 1.0000e-04
# Epoch 43/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.8238 - loss: 0.4727
# Epoch 43: val_accuracy did not improve from 0.79576
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 527ms/step - accuracy: 0.8237 - loss: 0.4729 - val_accuracy: 0.7595 - val_loss: 0.6048 - learning_rate: 1.0000e-04
# Epoch 44/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.8179 - loss: 0.4979
# Epoch 44: val_accuracy did not improve from 0.79576
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 34s 405ms/step - accuracy: 0.8179 - loss: 0.4979 - val_accuracy: 0.7791 - val_loss: 0.5522 - learning_rate: 1.0000e-04
# Epoch 45/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8063 - loss: 0.5030
# Epoch 45: val_accuracy did not improve from 0.79576
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 32s 387ms/step - accuracy: 0.8065 - loss: 0.5027 - val_accuracy: 0.7821 - val_loss: 0.5692 - learning_rate: 1.0000e-04
# Epoch 46/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8403 - loss: 0.4392
# Epoch 46: val_accuracy did not improve from 0.79576
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 391ms/step - accuracy: 0.8402 - loss: 0.4395 - val_accuracy: 0.7897 - val_loss: 0.5838 - learning_rate: 1.0000e-04
# Epoch 47/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8210 - loss: 0.4574
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 47: val_accuracy improved from 0.79576 to 0.80030, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 702ms/step - accuracy: 0.8210 - loss: 0.4576 - val_accuracy: 0.8003 - val_loss: 0.5333 - learning_rate: 1.0000e-04
# Epoch 48/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8250 - loss: 0.4474
# Epoch 48: val_accuracy did not improve from 0.80030
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 514ms/step - accuracy: 0.8251 - loss: 0.4473 - val_accuracy: 0.8003 - val_loss: 0.5334 - learning_rate: 1.0000e-05
# Epoch 49/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8408 - loss: 0.4454
# Epoch 49: val_accuracy improved from 0.80030 to 0.80333, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 709ms/step - accuracy: 0.8407 - loss: 0.4455 - val_accuracy: 0.8033 - val_loss: 0.5254 - learning_rate: 1.0000e-05
# Epoch 50/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.8386 - loss: 0.4477
# Epoch 50: val_accuracy improved from 0.80333 to 0.80787, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 75s 907ms/step - accuracy: 0.8387 - loss: 0.4473 - val_accuracy: 0.8079 - val_loss: 0.5060 - learning_rate: 1.0000e-05
#
# Unfreezing later DenseNet201 layers for fine-tuning...
#
# Fine-tuning model...
# Epoch 51/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.6669 - loss: 1.1385
# Epoch 51: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 301s 538ms/step - accuracy: 0.6669 - loss: 1.1380 - val_accuracy: 0.7474 - val_loss: 0.9179 - learning_rate: 1.0000e-05
# Epoch 52/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7556 - loss: 0.7828
# Epoch 52: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.7556 - loss: 0.7828 - val_accuracy: 0.7519 - val_loss: 0.7871 - learning_rate: 1.0000e-05
# Epoch 53/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7767 - loss: 0.6546
# Epoch 53: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.7767 - loss: 0.6547 - val_accuracy: 0.7610 - val_loss: 0.7231 - learning_rate: 1.0000e-05
# Epoch 54/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8081 - loss: 0.5316
# Epoch 54: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.8080 - loss: 0.5316 - val_accuracy: 0.7791 - val_loss: 0.6405 - learning_rate: 1.0000e-05
# Epoch 55/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8098 - loss: 0.5389
# Epoch 55: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.8098 - loss: 0.5391 - val_accuracy: 0.7625 - val_loss: 0.7079 - learning_rate: 1.0000e-05
# Epoch 56/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8148 - loss: 0.5472
# Epoch 56: val_accuracy did not improve from 0.80787
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 241ms/step - accuracy: 0.8149 - loss: 0.5471 - val_accuracy: 0.8048 - val_loss: 0.5673 - learning_rate: 1.0000e-05
# Epoch 57/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8228 - loss: 0.5092
# Epoch 57: val_accuracy improved from 0.80787 to 0.83056, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 96s 583ms/step - accuracy: 0.8228 - loss: 0.5092 - val_accuracy: 0.8306 - val_loss: 0.5134 - learning_rate: 1.0000e-05
# Epoch 58/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8444 - loss: 0.4889
# Epoch 58: val_accuracy improved from 0.83056 to 0.84266, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 159s 686ms/step - accuracy: 0.8444 - loss: 0.4888 - val_accuracy: 0.8427 - val_loss: 0.4619 - learning_rate: 1.0000e-05
# Epoch 59/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8491 - loss: 0.4076
# Epoch 59: val_accuracy improved from 0.84266 to 0.84720, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 128s 778ms/step - accuracy: 0.8492 - loss: 0.4075 - val_accuracy: 0.8472 - val_loss: 0.4566 - learning_rate: 1.0000e-05
# Epoch 60/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8574 - loss: 0.3976
# Epoch 60: val_accuracy did not improve from 0.84720
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 68s 324ms/step - accuracy: 0.8574 - loss: 0.3976 - val_accuracy: 0.8215 - val_loss: 0.4883 - learning_rate: 1.0000e-05
# Epoch 61/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8704 - loss: 0.3573
# Epoch 61: val_accuracy did not improve from 0.84720
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 270ms/step - accuracy: 0.8703 - loss: 0.3575 - val_accuracy: 0.8381 - val_loss: 0.4271 - learning_rate: 1.0000e-05
# Epoch 62/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8713 - loss: 0.3588
# Epoch 62: val_accuracy did not improve from 0.84720
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 241ms/step - accuracy: 0.8713 - loss: 0.3587 - val_accuracy: 0.8396 - val_loss: 0.4356 - learning_rate: 1.0000e-05
# Epoch 63/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8777 - loss: 0.3428
# Epoch 63: val_accuracy did not improve from 0.84720
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.8778 - loss: 0.3427 - val_accuracy: 0.8427 - val_loss: 0.4058 - learning_rate: 1.0000e-05
# Epoch 64/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8936 - loss: 0.3243
# Epoch 64: val_accuracy improved from 0.84720 to 0.85930, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 136s 824ms/step - accuracy: 0.8936 - loss: 0.3243 - val_accuracy: 0.8593 - val_loss: 0.3953 - learning_rate: 1.0000e-05
# Epoch 65/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8881 - loss: 0.3113
# Epoch 65: val_accuracy improved from 0.85930 to 0.86838, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 152s 884ms/step - accuracy: 0.8881 - loss: 0.3114 - val_accuracy: 0.8684 - val_loss: 0.3596 - learning_rate: 1.0000e-05
# Epoch 66/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8938 - loss: 0.2942
# Epoch 66: val_accuracy did not improve from 0.86838
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 51s 308ms/step - accuracy: 0.8938 - loss: 0.2942 - val_accuracy: 0.8638 - val_loss: 0.3636 - learning_rate: 1.0000e-05
# Epoch 67/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9043 - loss: 0.2532
# Epoch 67: val_accuracy improved from 0.86838 to 0.88654, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9043 - loss: 0.2532 - val_accuracy: 0.8865 - val_loss: 0.3546 - learning_rate: 1.0000e-05
# Epoch 68/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9136 - loss: 0.2854
# Epoch 68: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 53s 318ms/step - accuracy: 0.9136 - loss: 0.2854 - val_accuracy: 0.8457 - val_loss: 0.4191 - learning_rate: 1.0000e-05
# Epoch 69/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9048 - loss: 0.2755
# Epoch 69: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 46s 277ms/step - accuracy: 0.9048 - loss: 0.2754 - val_accuracy: 0.8775 - val_loss: 0.3374 - learning_rate: 1.0000e-05
# Epoch 70/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9197 - loss: 0.2414
# Epoch 70: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9197 - loss: 0.2415 - val_accuracy: 0.8714 - val_loss: 0.3431 - learning_rate: 1.0000e-05
# Epoch 71/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9168 - loss: 0.2439
# Epoch 71: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9168 - loss: 0.2439 - val_accuracy: 0.8548 - val_loss: 0.3758 - learning_rate: 1.0000e-05
# Epoch 72/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9298 - loss: 0.1992
# Epoch 72: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9298 - loss: 0.1993 - val_accuracy: 0.8699 - val_loss: 0.3138 - learning_rate: 1.0000e-05
# Epoch 73/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9298 - loss: 0.2084
# Epoch 73: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9298 - loss: 0.2084 - val_accuracy: 0.8472 - val_loss: 0.3841 - learning_rate: 1.0000e-05
# Epoch 74/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9300 - loss: 0.2102
# Epoch 74: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9300 - loss: 0.2102 - val_accuracy: 0.8608 - val_loss: 0.3948 - learning_rate: 1.0000e-05
# Epoch 75/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9328 - loss: 0.1911
# Epoch 75: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9328 - loss: 0.1912 - val_accuracy: 0.8820 - val_loss: 0.3149 - learning_rate: 1.0000e-05
# Epoch 76/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9331 - loss: 0.1920
# Epoch 76: val_accuracy did not improve from 0.88654
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9331 - loss: 0.1920 - val_accuracy: 0.8744 - val_loss: 0.3292 - learning_rate: 1.0000e-05
# Epoch 77/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9405 - loss: 0.1777
# Epoch 77: val_accuracy improved from 0.88654 to 0.90166, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 122s 743ms/step - accuracy: 0.9405 - loss: 0.1779 - val_accuracy: 0.9017 - val_loss: 0.2762 - learning_rate: 1.0000e-05
# Epoch 78/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9364 - loss: 0.2014
# Epoch 78: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 54s 325ms/step - accuracy: 0.9364 - loss: 0.2013 - val_accuracy: 0.8956 - val_loss: 0.2918 - learning_rate: 1.0000e-05
# Epoch 79/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9381 - loss: 0.1683
# Epoch 79: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 69s 248ms/step - accuracy: 0.9381 - loss: 0.1683 - val_accuracy: 0.8880 - val_loss: 0.2966 - learning_rate: 1.0000e-05
# Epoch 80/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9431 - loss: 0.1800
# Epoch 80: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - accuracy: 0.9430 - loss: 0.1801 - val_accuracy: 0.8880 - val_loss: 0.3140 - learning_rate: 1.0000e-05
# Epoch 81/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9502 - loss: 0.1475
# Epoch 81: val_accuracy did not improve from 0.90166
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9502 - loss: 0.1475 - val_accuracy: 0.8986 - val_loss: 0.2970 - learning_rate: 1.0000e-05
# Epoch 82/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9302 - loss: 0.1987
# Epoch 82: val_accuracy improved from 0.90166 to 0.91377, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 130s 794ms/step - accuracy: 0.9302 - loss: 0.1986 - val_accuracy: 0.9138 - val_loss: 0.2625 - learning_rate: 1.0000e-05
# Epoch 83/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9425 - loss: 0.1576
# Epoch 83: val_accuracy did not improve from 0.91377
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 66s 332ms/step - accuracy: 0.9425 - loss: 0.1577 - val_accuracy: 0.9138 - val_loss: 0.2727 - learning_rate: 1.0000e-05
# Epoch 84/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9462 - loss: 0.1585
# Epoch 84: val_accuracy did not improve from 0.91377
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 253ms/step - accuracy: 0.9462 - loss: 0.1586 - val_accuracy: 0.8911 - val_loss: 0.2917 - learning_rate: 1.0000e-05
# Epoch 85/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9430 - loss: 0.1679
# Epoch 85: val_accuracy did not improve from 0.91377
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 80s 243ms/step - accuracy: 0.9430 - loss: 0.1678 - val_accuracy: 0.8835 - val_loss: 0.3141 - learning_rate: 1.0000e-05
# Epoch 86/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9453 - loss: 0.1651
# Epoch 86: val_accuracy did not improve from 0.91377
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9453 - loss: 0.1651 - val_accuracy: 0.9062 - val_loss: 0.2888 - learning_rate: 1.0000e-05
# Epoch 87/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9497 - loss: 0.1395
# Epoch 87: val_accuracy improved from 0.91377 to 0.91831, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 128s 776ms/step - accuracy: 0.9497 - loss: 0.1395 - val_accuracy: 0.9183 - val_loss: 0.2872 - learning_rate: 1.0000e-05
# Epoch 88/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9278 - loss: 0.2045
# Epoch 88: val_accuracy did not improve from 0.91831
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 52s 312ms/step - accuracy: 0.9279 - loss: 0.2041 - val_accuracy: 0.9092 - val_loss: 0.2899 - learning_rate: 1.0000e-05
# Epoch 89/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9415 - loss: 0.1542
# Epoch 89: val_accuracy did not improve from 0.91831
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 71s 247ms/step - accuracy: 0.9415 - loss: 0.1543 - val_accuracy: 0.9017 - val_loss: 0.2783 - learning_rate: 1.0000e-05
# Epoch 90/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9504 - loss: 0.1301
# Epoch 90: val_accuracy improved from 0.91831 to 0.92436, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 127s 771ms/step - accuracy: 0.9504 - loss: 0.1302 - val_accuracy: 0.9244 - val_loss: 0.2609 - learning_rate: 1.0000e-05
# Epoch 91/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9532 - loss: 0.1248
# Epoch 91: val_accuracy did not improve from 0.92436
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 67s 315ms/step - accuracy: 0.9532 - loss: 0.1248 - val_accuracy: 0.9183 - val_loss: 0.2892 - learning_rate: 1.0000e-05
# Epoch 92/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9498 - loss: 0.1540
# Epoch 92: val_accuracy did not improve from 0.92436
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 252ms/step - accuracy: 0.9498 - loss: 0.1539 - val_accuracy: 0.9213 - val_loss: 0.2822 - learning_rate: 1.0000e-05
# Epoch 93/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9536 - loss: 0.1246
# Epoch 93: val_accuracy did not improve from 0.92436
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 82s 251ms/step - accuracy: 0.9536 - loss: 0.1247 - val_accuracy: 0.9168 - val_loss: 0.2476 - learning_rate: 1.0000e-05
# Epoch 94/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9572 - loss: 0.1338
# Epoch 94: val_accuracy did not improve from 0.92436
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9572 - loss: 0.1337 - val_accuracy: 0.9032 - val_loss: 0.3021 - learning_rate: 1.0000e-05
# Epoch 95/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9605 - loss: 0.1202
# Epoch 95: val_accuracy improved from 0.92436 to 0.93192, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 137s 832ms/step - accuracy: 0.9605 - loss: 0.1202 - val_accuracy: 0.9319 - val_loss: 0.2443 - learning_rate: 1.0000e-05
# Epoch 96/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9625 - loss: 0.1290
# Epoch 96: val_accuracy did not improve from 0.93192
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 60s 331ms/step - accuracy: 0.9625 - loss: 0.1290 - val_accuracy: 0.9002 - val_loss: 0.3344 - learning_rate: 1.0000e-05
# Epoch 97/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9521 - loss: 0.1493
# Epoch 97: val_accuracy improved from 0.93192 to 0.94100, saving model to /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 139s 845ms/step - accuracy: 0.9521 - loss: 0.1492 - val_accuracy: 0.9410 - val_loss: 0.2593 - learning_rate: 1.0000e-05
# Epoch 98/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9572 - loss: 0.1236
# Epoch 98: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 52s 313ms/step - accuracy: 0.9572 - loss: 0.1236 - val_accuracy: 0.9380 - val_loss: 0.2489 - learning_rate: 1.0000e-05
# Epoch 99/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9646 - loss: 0.1104
# Epoch 99: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 71s 245ms/step - accuracy: 0.9646 - loss: 0.1104 - val_accuracy: 0.9289 - val_loss: 0.2805 - learning_rate: 1.0000e-05
# Epoch 100/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9635 - loss: 0.0967
# Epoch 100: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - accuracy: 0.9635 - loss: 0.0967 - val_accuracy: 0.9228 - val_loss: 0.2697 - learning_rate: 1.0000e-05
# Epoch 101/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9628 - loss: 0.1000
# Epoch 101: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 240ms/step - accuracy: 0.9628 - loss: 0.1001 - val_accuracy: 0.9183 - val_loss: 0.2681 - learning_rate: 1.0000e-05
# Epoch 102/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9676 - loss: 0.0958
# Epoch 102: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 241ms/step - accuracy: 0.9676 - loss: 0.0958 - val_accuracy: 0.9334 - val_loss: 0.2592 - learning_rate: 1.0000e-05
# Epoch 103/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9651 - loss: 0.1239
# Epoch 103: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9651 - loss: 0.1239 - val_accuracy: 0.9244 - val_loss: 0.2635 - learning_rate: 1.0000e-05
# Epoch 104/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9654 - loss: 0.1069
# Epoch 104: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - accuracy: 0.9654 - loss: 0.1069 - val_accuracy: 0.9168 - val_loss: 0.2689 - learning_rate: 1.0000e-05
# Epoch 105/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9716 - loss: 0.0803
# Epoch 105: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 105: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - accuracy: 0.9716 - loss: 0.0803 - val_accuracy: 0.9228 - val_loss: 0.2685 - learning_rate: 1.0000e-05
# Epoch 106/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9654 - loss: 0.0934
# Epoch 106: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9654 - loss: 0.0934 - val_accuracy: 0.9228 - val_loss: 0.2712 - learning_rate: 1.0000e-06
# Epoch 107/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9614 - loss: 0.1037
# Epoch 107: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9614 - loss: 0.1037 - val_accuracy: 0.9244 - val_loss: 0.2608 - learning_rate: 1.0000e-06
# Epoch 108/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9601 - loss: 0.1223
# Epoch 108: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9602 - loss: 0.1222 - val_accuracy: 0.9244 - val_loss: 0.2626 - learning_rate: 1.0000e-06
# Epoch 109/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9770 - loss: 0.0750
# Epoch 109: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9770 - loss: 0.0750 - val_accuracy: 0.9289 - val_loss: 0.2530 - learning_rate: 1.0000e-06
# Epoch 110/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9706 - loss: 0.0879
# Epoch 110: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9706 - loss: 0.0879 - val_accuracy: 0.9304 - val_loss: 0.2572 - learning_rate: 1.0000e-06
# Epoch 111/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9682 - loss: 0.0922
# Epoch 111: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - accuracy: 0.9682 - loss: 0.0922 - val_accuracy: 0.9319 - val_loss: 0.2556 - learning_rate: 1.0000e-06
# Epoch 112/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9715 - loss: 0.0932
# Epoch 112: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 82s 250ms/step - accuracy: 0.9714 - loss: 0.0932 - val_accuracy: 0.9304 - val_loss: 0.2567 - learning_rate: 1.0000e-06
# Epoch 113/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9687 - loss: 0.0895
# Epoch 113: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9687 - loss: 0.0894 - val_accuracy: 0.9289 - val_loss: 0.2556 - learning_rate: 1.0000e-06
# Epoch 114/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9680 - loss: 0.0880
# Epoch 114: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9680 - loss: 0.0879 - val_accuracy: 0.9319 - val_loss: 0.2549 - learning_rate: 1.0000e-06
# Epoch 115/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9708 - loss: 0.0932
# Epoch 115: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9708 - loss: 0.0932 - val_accuracy: 0.9304 - val_loss: 0.2582 - learning_rate: 1.0000e-06
# Epoch 116/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9685 - loss: 0.0993
# Epoch 116: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9686 - loss: 0.0992 - val_accuracy: 0.9334 - val_loss: 0.2577 - learning_rate: 1.0000e-06
# Epoch 117/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9682 - loss: 0.0848
# Epoch 117: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9682 - loss: 0.0848 - val_accuracy: 0.9304 - val_loss: 0.2601 - learning_rate: 1.0000e-06
# Epoch 118/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9646 - loss: 0.1130
# Epoch 118: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9646 - loss: 0.1129 - val_accuracy: 0.9334 - val_loss: 0.2573 - learning_rate: 1.0000e-06
# Epoch 119/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9716 - loss: 0.0833
# Epoch 119: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9716 - loss: 0.0834 - val_accuracy: 0.9349 - val_loss: 0.2579 - learning_rate: 1.0000e-06
# Epoch 120/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9778 - loss: 0.0616
# Epoch 120: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9778 - loss: 0.0616 - val_accuracy: 0.9334 - val_loss: 0.2537 - learning_rate: 1.0000e-06
# Epoch 121/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9693 - loss: 0.0944
# Epoch 121: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9693 - loss: 0.0944 - val_accuracy: 0.9319 - val_loss: 0.2532 - learning_rate: 1.0000e-06
# Epoch 122/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9733 - loss: 0.0794
# Epoch 122: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9733 - loss: 0.0794 - val_accuracy: 0.9304 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 123/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9753 - loss: 0.0848
# Epoch 123: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9754 - loss: 0.0848 - val_accuracy: 0.9334 - val_loss: 0.2527 - learning_rate: 1.0000e-06
# Epoch 124/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9711 - loss: 0.0820
# Epoch 124: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9711 - loss: 0.0821 - val_accuracy: 0.9319 - val_loss: 0.2616 - learning_rate: 1.0000e-06
# Epoch 125/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9691 - loss: 0.0945
# Epoch 125: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9691 - loss: 0.0945 - val_accuracy: 0.9319 - val_loss: 0.2575 - learning_rate: 1.0000e-06
# Epoch 126/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9664 - loss: 0.0920
# Epoch 126: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9664 - loss: 0.0920 - val_accuracy: 0.9319 - val_loss: 0.2547 - learning_rate: 1.0000e-06
# Epoch 127/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9762 - loss: 0.0809
# Epoch 127: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9762 - loss: 0.0808 - val_accuracy: 0.9319 - val_loss: 0.2548 - learning_rate: 1.0000e-06
# Epoch 128/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9648 - loss: 0.0983
# Epoch 128: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - accuracy: 0.9649 - loss: 0.0982 - val_accuracy: 0.9304 - val_loss: 0.2508 - learning_rate: 1.0000e-06
# Epoch 129/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9682 - loss: 0.0859
# Epoch 129: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9682 - loss: 0.0860 - val_accuracy: 0.9319 - val_loss: 0.2551 - learning_rate: 1.0000e-06
# Epoch 130/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9732 - loss: 0.0791
# Epoch 130: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9732 - loss: 0.0791 - val_accuracy: 0.9304 - val_loss: 0.2524 - learning_rate: 1.0000e-06
# Epoch 131/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9813 - loss: 0.0597
# Epoch 131: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9812 - loss: 0.0597 - val_accuracy: 0.9334 - val_loss: 0.2503 - learning_rate: 1.0000e-06
# Epoch 132/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9668 - loss: 0.0847
# Epoch 132: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 43s 258ms/step - accuracy: 0.9669 - loss: 0.0847 - val_accuracy: 0.9334 - val_loss: 0.2545 - learning_rate: 1.0000e-06
# Epoch 133/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9780 - loss: 0.0643
# Epoch 133: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - accuracy: 0.9780 - loss: 0.0644 - val_accuracy: 0.9349 - val_loss: 0.2490 - learning_rate: 1.0000e-06
# Epoch 134/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9756 - loss: 0.0697
# Epoch 134: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9756 - loss: 0.0697 - val_accuracy: 0.9349 - val_loss: 0.2496 - learning_rate: 1.0000e-06
# Epoch 135/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9704 - loss: 0.0943
# Epoch 135: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9704 - loss: 0.0943 - val_accuracy: 0.9334 - val_loss: 0.2483 - learning_rate: 1.0000e-06
# Epoch 136/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9709 - loss: 0.0801
# Epoch 136: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 244ms/step - accuracy: 0.9709 - loss: 0.0801 - val_accuracy: 0.9334 - val_loss: 0.2540 - learning_rate: 1.0000e-06
# Epoch 137/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9737 - loss: 0.0757
# Epoch 137: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9737 - loss: 0.0757 - val_accuracy: 0.9349 - val_loss: 0.2515 - learning_rate: 1.0000e-06
# Epoch 138/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9741 - loss: 0.0838
# Epoch 138: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - accuracy: 0.9741 - loss: 0.0837 - val_accuracy: 0.9380 - val_loss: 0.2480 - learning_rate: 1.0000e-06
# Epoch 139/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9803 - loss: 0.0803
# Epoch 139: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9803 - loss: 0.0803 - val_accuracy: 0.9319 - val_loss: 0.2450 - learning_rate: 1.0000e-06
# Epoch 140/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9770 - loss: 0.0694
# Epoch 140: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9770 - loss: 0.0693 - val_accuracy: 0.9365 - val_loss: 0.2447 - learning_rate: 1.0000e-06
# Epoch 141/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9754 - loss: 0.0744
# Epoch 141: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - accuracy: 0.9754 - loss: 0.0744 - val_accuracy: 0.9380 - val_loss: 0.2439 - learning_rate: 1.0000e-06
# Epoch 142/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9755 - loss: 0.0794
# Epoch 142: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9755 - loss: 0.0794 - val_accuracy: 0.9365 - val_loss: 0.2529 - learning_rate: 1.0000e-06
# Epoch 143/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9824 - loss: 0.0579
# Epoch 143: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9824 - loss: 0.0580 - val_accuracy: 0.9349 - val_loss: 0.2641 - learning_rate: 1.0000e-06
# Epoch 144/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9769 - loss: 0.0750
# Epoch 144: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.9769 - loss: 0.0750 - val_accuracy: 0.9319 - val_loss: 0.2583 - learning_rate: 1.0000e-06
# Epoch 145/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9764 - loss: 0.0813
# Epoch 145: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9764 - loss: 0.0813 - val_accuracy: 0.9365 - val_loss: 0.2604 - learning_rate: 1.0000e-06
# Epoch 146/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9660 - loss: 0.0859
# Epoch 146: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.9660 - loss: 0.0859 - val_accuracy: 0.9365 - val_loss: 0.2570 - learning_rate: 1.0000e-06
# Epoch 147/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9760 - loss: 0.0679
# Epoch 147: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9760 - loss: 0.0679 - val_accuracy: 0.9380 - val_loss: 0.2574 - learning_rate: 1.0000e-06
# Epoch 148/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9799 - loss: 0.0689
# Epoch 148: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.9799 - loss: 0.0689 - val_accuracy: 0.9365 - val_loss: 0.2589 - learning_rate: 1.0000e-06
# Epoch 149/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9797 - loss: 0.0671
# Epoch 149: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9797 - loss: 0.0671 - val_accuracy: 0.9365 - val_loss: 0.2589 - learning_rate: 1.0000e-06
# Epoch 150/150
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9762 - loss: 0.0677
# Epoch 150: val_accuracy did not improve from 0.94100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 247ms/step - accuracy: 0.9762 - loss: 0.0677 - val_accuracy: 0.9365 - val_loss: 0.2581 - learning_rate: 1.0000e-06
#
# Loading the best model from /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step
#
# Confusion Matrix:
# [[199   5   0   0   0]
#  [  6 185   2   0   0]
#  [  2  12  74   5   0]
#  [  0   2   1  85   1]
#  [  0   0   3   0  79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      0Normal       0.96      0.98      0.97       204
#    1Doubtful       0.91      0.96      0.93       193
#        2Mild       0.93      0.80      0.86        93
#    3Moderate       0.94      0.96      0.95        89
#      4Severe       0.99      0.96      0.98        82
#
#     accuracy                           0.94       661
#    macro avg       0.95      0.93      0.94       661
# weighted avg       0.94      0.94      0.94       661
# Sample predictions on test set:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# The best model has been saved to: /content/drive/MyDrive/KneeOA/densenet201_best_model.keras
